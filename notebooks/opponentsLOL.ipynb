# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로 이 클래스는 RIOT API를 불러오기만 하고,
    파싱 클래스는 opponentsParser 이용
    
    """
    url='https://kr.api.riotgames.com'
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    query_queue="?queue=420"
    #timeline url
    
    
    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["accountId"]
    

    def get_summoner_raw(self,summoner_name):
            #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                        RiotApi.url_summoner_v4+
                        summoner_name+
                        RiotApi.query+self._apikey).json()
        return summoner_data
    
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byAccountid(self,account_id):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        
        ## 추가. 05.11. queryparameter를 추가하여, queue가 420 (rank 5vs5 만 가져온다.)
        ## 추가. 05.11. match중 lane="NONE"은 다시하기 게임이라서 제외함.
        
        account_id=str(account_id)

        print(RiotApi.url+RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey)
        
        game_data=requests.get(RiotApi.url+
                            RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey).json()
        print(game_data)
        matches=[]
        for match in game_data["matches"]:
            if match["lane"]!="NONE" :
                matches.append(match['gameId'])
        return matches
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="RGAPI-f7922aa7-1787-4f61-be99-432393122bc2")
    print(test.get_league(1))
    #user_accountId=test.get_summoner('종버버버')
    user_accountId='anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4'
    games_ids=test.get_gameid_byAccountid(user_accountId)
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    
    
    
    #print(test.get_league('1').json())
    
    #games_data
    
#games_ids
#print(len(games_ids))
#test_timeline
#games_ids
# Out:
# RiotApi init
# [{'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'kO1_5h8JDC1eRWEbBSp1Ww3_i-k_5oaathQ6FPmh1P_F1CeprkAx8eknbA', 'summonerName': 'asjdjgnsdg', 'leaguePoints': 727, 'wins': 121, 'losses': 92, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'O5VBYQREtpBWwO71wdx1Y9G4G5uznKYzWDol8ug7iVTlUYw5naqB96wDqg', 'summonerName': '쿠자니자니', 'leaguePoints': 721, 'wins': 201, 'losses': 160, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'vlkmAJKC1xD1EcY3nCRYCBTWLRsKknZCQCD0Jxx-PeZWaiA', 'summonerName': 'Hengzzz', 'leaguePoints': 708, 'wins': 307, 'losses': 266, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'B3AP5P6dGw42VEkIrFmMNeq7mMiBCCWHoAsh35uLN-uQ8-4', 'summonerName': '15 March', 'leaguePoints': 702, 'wins': 210, 'losses': 169, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'p2Re8DlKDG6R1_UisV7__sSVfUnqbpAkHlfWl8JpRkMnw1c', 'summonerName': 'ZED99', 'leaguePoints': 702, 'wins': 195, 'losses': 164, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'ZaaWSs0bWJPXMEJzSlxec4-oiFBrGIbpJiqUt0CnkkwJOh8', 'summonerName': 'Indexy', 'leaguePoints': 696, 'wins': 532, 'losses': 495, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'xYbIlC3EMpM1R1lk6uW_AknnyCfUabhBDI_1BWYypMcPUQ', 'summonerName': '아이디짓기귀찬아', 'leaguePoints': 694, 'wins': 522, 'losses': 438, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'hBbKBMQeosyaGLEAgNHcOD0jwXsNUVlVxIzalWY0tXLoCa4', 'summonerName': '쌍둥이그림자모험', 'leaguePoints': 686, 'wins': 248, 'losses': 213, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'PY7wgSq28x4cDtibfBBdV8VvMP6T7Wb1HHzYxiGeNMIivis', 'summonerName': '광명불꽃턱', 'leaguePoints': 682, 'wins': 308, 'losses': 272, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'czJrOzvSL_AUaElhRnDkkuCl3RPBCXHRGMFwyMWH_cVnLiA', 'summonerName': '한 여름의 서리', 'leaguePoints': 680, 'wins': 216, 'losses': 169, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '8gAR-X4hjfuYWZfHZuL4MO6J9MmK38qzR0dICucGNv6Eyswt', 'summonerName': '잉어킹4세', 'leaguePoints': 679, 'wins': 953, 'losses': 909, 'veteran': True, 'inactive': False, 'freshBlood': False, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'FAynNxZXJX3FIC1mPmHZBUwBndjMP9TqyI4VcNQYLsetRok', 'summonerName': '111111111112', 'leaguePoints': 679, 'wins' ...
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4?queue=420&api_key=RGAPI-f7922aa7-1787-4f61-be99-432393122bc2
# {'matches': [{'platformId': 'KR', 'gameId': 4052319398, 'champion': 106, 'queue': 420, 'season': 13, 'timestamp': 1577554592890, 'role': 'NONE', 'lane': 'JUNGLE'}, {'platformId': 'KR', 'gameId': 4051444769, 'champion': 106, 'queue': 420, 'season': 13, 'timestamp': 1577531044785, 'role': 'NONE', 'lane': 'JUNGLE'}, {'platformId': 'KR', 'gameId': 4051274708, 'champion': 60, 'queue': 420, 'season': 13, 'timestamp': 1577528178977, 'role': 'NONE', 'lane': 'JUNGLE'}], 'startIndex': 0, 'endIndex': 3, 'totalGames': 3}
