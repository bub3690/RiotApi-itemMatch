# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로 이 클래스는 RIOT API를 불러오기만 하고,
    파싱 클래스는 opponentsParser 이용
    
    """
    url='https://kr.api.riotgames.com'
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    query_queue="?queue=420"## 랭크 5vs5 게임만 출력위해서 get_gameid_byAccountid 함수에서 사용.
    #timeline url
    
    
    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["accountId"]
    

    def get_summoner_raw(self,summoner_name):
            #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                        RiotApi.url_summoner_v4+
                        summoner_name+
                        RiotApi.query+self._apikey).json()
        return summoner_data
    
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byAccountid(self,account_id):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        
        ## 추가. 05.11. queryparameter를 추가하여, queue가 420 (rank 5vs5 만 가져온다.)
        ## 추가. 05.11. match중 lane="NONE"은 다시하기 게임이라서 제외함.
        
        account_id=str(account_id)

        print(RiotApi.url+RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey)
        
        game_data=requests.get(RiotApi.url+
                            RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey).json()
        print(game_data)
        matches=[]
        for match in game_data["matches"]:
            if match["lane"]!="NONE" :
                matches.append(match['gameId'])
        return matches
    
    def get_match_byMatchid(self,match_id):
        """
        print(RiotApi.url+RiotApi.url_match_v4_matchid
                            +match_id
                            +RiotApi.query
                            +self._apikey)
        """
        return requests.get(RiotApi.url+RiotApi.url_match_v4_matchid
                            +match_id
                            +RiotApi.query
                            +self._apikey).json()
    
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="RGAPI-4f2f2528-6425-4f2b-a67d-b3b777dd17a1")
    #print(test.get_league(1))
    #user_accountId=test.get_summoner('종버버버')
    #user_accountId='anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4'
    #games_ids=test.get_gameid_byAccountid(user_accountId)
    #match_info = test.get_match_byMatchid('4052319398')#match_v4 test
    time_line=test.get_timeline_byMatchid('4052319398')
    
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    
    
    
    #print(test.get_league('1').json())
    
    #games_data
    
#games_ids
#match_info
#print(len(games_ids))
#test_timeline
#games_ids
#time_line
# Out:
# RiotApi init
# {'frames': [{'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 560, 'y': 581},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 560, 'y': 361},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 351, 'y': 293},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 221, 'y': 471},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 311, 'y': 649},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 14486, 'y': 14511},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 14486, 'y': 14291},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 14277, 'y': 14223},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 14147, 'y': 14401},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 14237, 'y': 14579},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [],
#    'timestamp': 0},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 822, 'y': 9846},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 8835, 'y': 3492},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6283, 'y': 6449},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 7957, 'y': 3486},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 8681, 'y': 3436},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 1752, 'y': 12882},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 10205, 'y': 7257},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 8761, 'y': 7420},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 9900, 'y': 6536},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 10074, 'y': 7074},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_PURCHASED',
#      'timestamp': 2925,
#      'participantId': 8,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 3290,
#      'participantId': 7,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 3555,
#      'participantId': 7,
#      'itemId': 1039},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 3729,
#      'participantId': 7,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 4290,
#      'participantId': 4,
#      'itemId': 1054},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 4488,
#      'participantId': 4,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 4719,
#      'participantId': 4,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 5070,
#      'participantId': 8,
#      'itemId': 1056},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 5565,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 5796,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 6128,
#      'participantId': 10,
#      'itemId': 1055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 6227,
#      'participantId': 10,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 6462,
#      'participantId': 10,
#      'itemId': 3340},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 6693,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7263,
#      'participantId': 5,
#      'itemId': 1055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 7458,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7656,
#      'participantId': 2,
#      'itemId': 1041},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7920,
#      'participantId': 6,
#      'itemId': 2033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7993,
#      'participantId': 2,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 8125,
#      'participantId': 5,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 8356,
#      'participantId': 2,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 9131,
#      'participantId': 6,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 15511,
#      'participantId': 1,
#      'itemId': 3854},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16387,
#      'participantId': 1,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 16453,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16599,
#      'participantId': 1,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16731,
#      'participantId': 9,
#      'itemId': 3850},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16898,
#      'participantId': 1,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17063,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17229,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17435,
#      'participantId': 3,
#      'itemId': 2033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17568,
#      'participantId': 9,
#      'itemId': 3340},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 24818,
#      'participantId': 6,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 26789,
#      'participantId': 10,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 53514,
#      'participantId': 7,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 60002},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 1186, 'y': 10504},
#      'currentGold': 20,
#      'totalGold': 520,
#      'level': 1,
#      'xp': 60,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 3624, 'y': 7911},
#      'currentGold': 120,
#      'totalGold': 620,
#      'level': 2,
#      'xp': 330,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 7473, 'y': 7302},
#      'currentGold': 111,
#      'totalGold': 611,
#      'level': 1,
#      'xp': 240,
#      'minionsKilled': 5,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 12276, 'y': 2256},
#      'currentGold': 97,
#      'totalGold': 597,
#      'level': 1,
#      'xp': 131,
#      'minionsKilled': 4,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 12394, 'y': 2780},
#      'currentGold': 22,
#      'totalGold': 522,
#      'level': 1,
#      'xp': 131,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 1541, 'y': 11384},
#      'currentGold': 125,
#      'totalGold': 625,
#      'level': 1,
#      'xp': 270,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 12212, 'y': 6525},
#      'currentGold': 120,
#      'totalGold': 620,
#      'level': 2,
#      'xp': 330,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 8004, 'y': 7699},
#      'currentGold': 97,
#      'totalGold': 597,
#      'level': 1,
#      'xp': 211,
#      'minionsKilled': 4,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 13271, 'y': 2779},
#      'currentGold': 83,
#      'totalGold': 583,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13112, 'y': 2518},
#      'currentGold': 22,
#      'totalGold': 522,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 61431,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 74992,
#      'participantId': 2,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 89174,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 101312,
#      'participantId': 3,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 105379,
#      'participantId': 2,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 106199,
#      'participantId': 7,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 120037},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 924, 'y': 10665},
#      'currentGold': 302,
#      'totalGold': 802,
#      'level': 3,
#      'xp': 662,
#      'minionsKilled': 8,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 3621, 'y': 10135},
#      'currentGold': 448,
#      'totalGold': 948,
#      'level': 3,
#      'xp': 680,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 12,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6582, 'y': 6830},
#      'currentGold': 360,
#      'totalGold': 860,
#      'level': 3,
#      'xp': 663,
#      'minionsKilled': 11,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 12168, 'y': 2456},
#      'currentGold': 360,
#      'totalGold': 860,
#      'level': 2,
#      'xp': 508,
#      'minionsKilled': 12,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 12733, 'y': 2058},
#      'currentGold': 213,
#      'totalGold': 713,
#      'level': 2,
#      'xp': 508,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 1829, 'y': 11494},
#      'currentGold': 388,
#      'totalGold': 888,
#      'level': 3,
#      'xp': 782,
#      'minionsKilled': 14,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 7641, 'y': 10991},
#      'currentGold': 518,
#      'totalGold': 1018,
#      'level': 3,
#      'xp': 805,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 7422, 'y': 7393},
#      'currentGold': 420,
#      'totalGold': 920,
#      'level': 3,
#      'xp': 904,
#      'minionsKilled': 13,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 12971, 'y': 3014},
#      'currentGold': 402,
#      'totalGold': 902,
#      'level': 2,
#      'xp': 450,
#      'minionsKilled': 14,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13233, 'y': 3026},
#      'currentGold': 262,
#      'totalGold': 762,
#      'level': 2,
#      'xp': 450,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 131746,
#      'participantId': 4,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 132473,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 135877,
#      'participantId': 8,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 140703,
#      'participantId': 9,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 141188,
#      'participantId': 10,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 141981,
#      'participantId': 5,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 143026,
#      'participantId': 1,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 149865,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 1},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 151483,
#      'participantId': 7,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 152820,
#      'participantId': 3,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 155105,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 155275,
#      'participantId': 9,
#      'itemId': 2010},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 156100,
#      'participantId': 5,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 156800,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 9},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 157690,
#      'participantId': 2,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 159535,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 161381,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 2},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 161688,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 161976,
#      'participantId': 1,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 167290,
#      'participantId': 8,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 169955,
#      'participantId': 4,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 177112,
#      'participantId': 6,
#      'itemId': 2010},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 178028,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 180078},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 848, 'y': 5856},
#      'currentGold': 45,
#      'totalGold': 1220,
#      'level': 3,
#      'xp': 1080,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 3803, 'y': 6314},
#      'currentGold': 1058,
#      'totalGold': 1558,
#      'level': 3,
#      'xp': 971,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6343, 'y': 6901},
#      'currentGold': 641,
#      'totalGold': 1141,
#      'level': 4,
#      'xp': 1446,
#      'minionsKilled': 18,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 6514, 'y': 1081},
#      'currentGold': 60,
#      'totalGold': 1060,
#      'level': 2,
#      'xp': 658,
#      'minionsKilled': 16,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 10221, 'y': 1248},
#      'currentGold': 348,
#      'totalGold': 848,
#      'level': 3,
#      'xp': 809,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 3604, 'y': 12928},
#      'currentGold': 136,
#      'totalGold': 1071,
#      'level': 3,
#      'xp': 904,
#      'minionsKilled': 15,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 8241, 'y': 10303},
#      'currentGold': 866,
#      'totalGold': 1366,
#      'level': 4,
#      'xp': 1182,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 24,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 7419, 'y': 7254},
#      'currentGold': 676,
#      'totalGold': 1176,
#      'level': 4,
#      'xp': 1446,
#      'minionsKilled': 21,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 11200, 'y': 1170},
#      'currentGold': 721,
#      'totalGold': 1221,
#      'level': 3,
#      'xp': 901,
#      'minionsKilled': 26,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 11100, 'y': 1336},
#      'currentGold': 427,
#      'totalGold': 927,
#      'level': 3,
#      'xp': 901,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_DESTROYED',
#      'timestamp': 183667,
#      'participantId': 5,
#      'itemId': 2010},
#     {'type': 'WARD_PLACED',
#      'timestamp': 191458,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 7},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 193255,
#      'participantId': 6,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 195390,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 197702,
#      'position': {'x': 2315, 'y': 12020},
#      'killerId': 2,
#      'victimId': 8,
#      'assistingParticipantIds': [3]},
#     {'type': 'WARD_PLACED',
#      'timestamp': 201438,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 205525,
#      'participantId': 9,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 206018,
#      'participantId': 10,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 210535,
#      'participantId': 8,
#      'itemId': 1052},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 211990,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 217150,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 221776,
#      'participantId': 3,
#      'itemId': 1054},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 222064,
#      'participantId': 5,
#      'itemId': 1083},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 224012,
#      'participantId': 5,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 224318,
#      'participantId': 3,
#      'itemId': 1006},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 226920,
#      'participantId': 7,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 227141,
#      'participantId': 3,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 227606,
#      'participantId': 1,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 240081},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 1276, 'y': 11108},
#      'currentGold': 413,
#      'totalGold': 1588,
#      'level': 5,
#      'xp': 1774,
#      'minionsKilled': 22,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 6989, 'y': 5401},
#      'currentGold': 1334,
#      'totalGold': 1834,
#      'level': 4,
#      'xp': 1241,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 23,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6967, 'y': 7581},
#      'currentGold': 910,
#      'totalGold': 1410,
#      'level': 5,
#      'xp': 1991,
#      'minionsKilled': 23,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 11971, 'y': 1982},
#      'currentGold': 453,
#      'totalGold': 1453,
#      'level': 4,
#      'xp': 1174,
#      'minionsKilled': 28,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 7384, 'y': 1141},
#      'currentGold': 191,
#      'totalGold': 1066,
#      'level': 4,
#      'xp': 1234,
#      'minionsKilled': 5,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 1436, 'y': 11226},
#      'currentGold': 447,
#      'totalGold': 1382,
#      'level': 4,
#      'xp': 1539,
#      'minionsKilled': 23,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 10943, 'y': 8417},
#      'currentGold': 1065,
#      'totalGold': 1565,
#      'level': 4,
#      'xp': 1358,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 28,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 7569, 'y': 7685},
#      'currentGold': 1015,
#      'totalGold': 1515,
#      'level': 5,
#      'xp': 2080,
#      'minionsKilled': 31,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 13352, 'y': 5387},
#      'currentGold': 78,
#      'totalGold': 1403,
#      'level': 3,
#      'xp': 939,
#      'minionsKilled': 26,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13453, 'y': 5869},
#      'currentGold': 62,
#      'totalGold': 1172,
#      'level': 3,
#      'xp': 939,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_DESTROYED',
#      'timestamp': 240733,
#      'participantId': 4,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 250759,
#      'participantId': 5,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 255365,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 7},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 255457,
#      'participantId': 1,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 256051,
#      'participantId': 10,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 261600,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 262826,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 264683,
#      'participantId': 6,
#      'itemId': 2010},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 267377,
#      'participantId': 3,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 269707,
#      'participantId': 10,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 269898,
#      'participantId': 10,
#      'itemId': 1036},
#     {'type': 'WARD_PLACED',
#      'timestamp': 270543,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 2},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 270543,
#      'participantId': 10,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 270543,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 270802,
#      'participantId': 10,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 272402,
#      'participantId': 9,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 273631,
#      'participantId': 9,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 274934,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 275263,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 279796,
#      'participantId': 1,
#      'itemId': 1001},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 282048,
#      'participantId': 1,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 283820,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 292480,
#      'participantId': 2,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 296322,
#      'participantId': 3,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 297298,
#      'participantId': 8,
#      'itemId': 2003}],
#    'timestamp': 300105},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 877, 'y': 10587},
#      'currentGold': 638,
#      'totalGold': 1813,
#      'level': 5,
#      'xp': 2255,
#      'minionsKilled': 27,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 12520, 'y': 1417},
#      'currentGold': 1473,
#      'totalGold': 1973,
#      'level': 4,
#      'xp': 1261,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 24,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6779, 'y': 7135},
#      'currentGold': 1246,
#      'totalGold': 1746,
#      'level': 6,
#      'xp': 2684,
#      'minionsKilled': 33,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 12439, 'y': 2830},
#      'currentGold': 709,
#      'totalGold': 1709,
#      'level': 4,
#      'xp': 1468,
#      'minionsKilled': 35,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 12808, 'y': 2462},
#      'currentGold': 336,
#      'totalGold': 1211,
#      'level': 4,
#      'xp': 1407,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 1402, 'y': 10938},
#      'currentGold': 766,
#      'totalGold': 1701,
#      'level': 5,
#      'xp': 2173,
#      'minionsKilled': 34,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 10536, 'y': 12468},
#      'currentGold': 253,
#      'totalGold': 1878,
#      'level': 4,
#      'xp': 1694,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 36,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 8534, 'y': 7511},
#      'currentGold': 1393,
#      'totalGold': 1893,
#      'level': 6,
#      'xp': 2714,
#      'minionsKilled': 43,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 13269, 'y': 3373},
#      'currentGold': 383,
#      'totalGold': 1708,
#      'level': 4,
#      'xp': 1333,
#      'minionsKilled': 36,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13471, 'y': 3307},
#      'currentGold': 197,
#      'totalGold': 1307,
#      'level': 4,
#      'xp': 1333,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 301199,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 316789,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 1},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 316789,
#      'participantId': 1,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 317107,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 320043,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 320555,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 1},
#     {'type': 'WARD_KILL',
#      'timestamp': 327178,
#      'wardType': 'YELLOW_TRINKET',
#      'killerId': 1},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 333997,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 334341,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 335621,
#      'participantId': 6,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 339666,
#      'participantId': 10,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 339699,
#      'participantId': 4,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 346729,
#      'participantId': 7,
#      'itemId': 3706},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 346729,
#      'participantId': 7,
#      'itemId': 1039},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 347234,
#      'participantId': 7,
#      'itemId': 1028},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 349465,
#      'participantId': 7,
#      'itemId': 3364},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 349465,
#      'participantId': 7,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 349764,
#      'participantId': 7,
#      'itemId': 2055}],
#    'timestamp': 360124},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 1284, 'y': 11440},
#      'currentGold': 118,
#      'totalGold': 1993,
#      'level': 6,
#      'xp': 2709,
#      'minionsKilled': 30,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 8504, 'y': 2626},
#      'currentGold': 1684,
#      'totalGold': 2184,
#      'level': 4,
#      'xp': 1457,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 24,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 1257, 'y': 1181},
#      'currentGold': 23,
#      'totalGold': 1973,
#      'level': 6,
#      'xp': 2985,
#      'minionsKilled': 39,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 12201, 'y': 2360},
#      'currentGold': 1447,
#      'totalGold': 2447,
#      'level': 5,
#      'xp': 2026,
#      'minionsKilled': 48,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 12615, 'y': 2740},
#      'currentGold': 653,
#      'totalGold': 1528,
#      'level': 5,
#      'xp': 1905,
#      'minionsKilled': 9,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 4181, 'y': 13627},
#      'currentGold': 1155,
#      'totalGold': 2090,
#      'level': 6,
#      'xp': 2594,
#      'minionsKilled': 42,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 6743, 'y': 7325},
#      'currentGold': 673,
#      'totalGold': 2298,
#      'level': 5,
#      'xp': 2323,
#      'minionsKilled': 4,
#      'jungleMinionsKilled': 40,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 13982, 'y': 13791},
#      'currentGold': 35,
#      'totalGold': 2385,
#      'level': 6,
#      'xp': 3123,
#      'minionsKilled': 47,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 13925, 'y': 11185},
#      'currentGold': 118,
#      'totalGold': 2043,
#      'level': 4,
#      'xp': 1615,
#      'minionsKilled': 46,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13741, 'y': 4133},
#      'currentGold': 361,
#      'totalGold': 1471,
#      'level': 4,
#      'xp': 1615,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_DESTROYED',
#      'timestamp': 364075,
#      'participantId': 5,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 364240,
#      'participantId': 6,
#      'itemId': 2010},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 368064,
#      'participantId': 3,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 368946,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 378194,
#      'participantId': 5,
#      'itemId': 2010},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 379667,
#      'participantId': 8,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 380630,
#      'participantId': 7,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 390994,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 7},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 390994,
#      'participantId': 7,
#      'itemId': 2055},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 393929,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 397762,
#      'position': {'x': 11838, 'y': 2376},
#      'killerId': 5,
#      'victimId': 10,
#      'assistingParticipantIds': [2, 1]},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 398954,
#      'participantId': 3,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 399185,
#      'participantId': 3,
#      'itemId': 1036},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 401127,
#      'position': {'x': 8246, 'y': 7493},
#      'killerId': 6,
#      'victimId': 4,
#      'assistingParticipantIds': [7]},
#     {'type': 'WARD_PLACED',
#      'timestamp': 403267,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 8},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 405231,
#      'participantId': 4,
#      'itemId': 3145},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 406224,
#      'participantId': 10,
#      'itemId': 1053},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 406224,
#      'participantId': 10,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 406751,
#      'participantId': 4,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 408064,
#      'participantId': 10,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 409703,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 8},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 411132,
#      'participantId': 5,
#      'itemId': 2010},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 412163,
#      'participantId': 6,
#      'itemId': 3196},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 412163,
#      'participantId': 6,
#      'itemId': 3200},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 414580,
#      'participantId': 4,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 414820,
#      'participantId': 6,
#      'itemId': 1056},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 415175,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 415377,
#      'participantId': 6,
#      'itemId': 1001},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 418005,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'EVOLVE'}],
#    'timestamp': 420126},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 2663, 'y': 13258},
#      'currentGold': 569,
#      'totalGold': 2444,
#      'level': 7,
#      'xp': 3614,
#      'minionsKilled': 45,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 394, 'y': 461},
#      'currentGold': 2031,
#      'totalGold': 2531,
#      'level': 5,
#      'xp': 1853,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 32,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 7098, 'y': 7176},
#      'currentGold': 173,
#      'totalGold': 2123,
#      'level': 6,
#      'xp': 3135,
#      'minionsKilled': 41,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 6325, 'y': 1084},
#      'currentGold': 140,
#      'totalGold': 2665,
#      'level': 5,
#      'xp': 2253,
#      'minionsKilled': 53,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 7606, 'y': 5146},
#      'currentGold': 126,
#      'totalGold': 1676,
#      'level': 5,
#      'xp': 2132,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 4216, 'y': 13662},
#      'currentGold': 237,
#      'totalGold': 2337,
#      'level': 6,
#      'xp': 3019,
#      'minionsKilled': 46,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 11277, 'y': 7060},
#      'currentGold': 942,
#      'totalGold': 2567,
#      'level': 6,
#      'xp': 2927,
#      'minionsKilled': 7,
#      'jungleMinionsKilled': 44,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 10804, 'y': 7509},
#      'currentGold': 241,
#      'totalGold': 2591,
#      'level': 7,
#      'xp': 3393,
#      'minionsKilled': 52,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 12175, 'y': 3345},
#      'currentGold': 463,
#      'totalGold': 2388,
#      'level': 5,
#      'xp': 2048,
#      'minionsKilled': 57,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 14244, 'y': 13760},
#      'currentGold': 42,
#      'totalGold': 1692,
#      'level': 5,
#      'xp': 2199,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 421245,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 426639,
#      'participantId': 8,
#      'itemId': 3916},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 426639,
#      'participantId': 8,
#      'itemId': 1052},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 426685,
#      'participantId': 7,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 427196,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 441316,
#      'participantId': 9,
#      'itemId': 2010},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 451649,
#      'participantId': 3,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 457696,
#      'participantId': 10,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 457906,
#      'participantId': 5,
#      'itemId': 1038},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 459233,
#      'participantId': 1,
#      'itemId': 3117},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 459233,
#      'participantId': 1,
#      'itemId': 1001},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 460202,
#      'participantId': 5,
#      'itemId': 1001},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 461136,
#      'participantId': 1,
#      'itemId': 2055},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 461958,
#      'participantId': 5,
#      'afterId': 0,
#      'beforeId': 1001},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 463252,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 463987,
#      'participantId': 5,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 464593,
#      'participantId': 5,
#      'itemId': 2055},
#     {'type': 'WARD_PLACED',
#      'timestamp': 467100,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 474391,
#      'participantId': 9,
#      'itemId': 3113},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 474391,
#      'participantId': 9,
#      'itemId': 1052},
#     {'type': 'WARD_PLACED',
#      'timestamp': 475034,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'WARD_PLACED',
#      'timestamp': 475562,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 4},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 475971,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 476106,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 476479,
#      'participantId': 2,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 479496,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 10},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 479496,
#      'participantId': 10,
#      'itemId': 2055}],
#    'timestamp': 480147},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 4026, 'y': 13950},
#      'currentGold': 1273,
#      'totalGold': 3148,
#      'level': 8,
#      'xp': 4583,
#      'minionsKilled': 58,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 3470, 'y': 8944},
#      'currentGold': 379,
#      'totalGold': 2754,
#      'level': 5,
#      'xp': 2029,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 36,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 6941, 'y': 6597},
#      'currentGold': 401,
#      'totalGold': 2351,
#      'level': 7,
#      'xp': 3709,
#      'minionsKilled': 47,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 13540, 'y': 3645},
#      'currentGold': 531,
#      'totalGold': 3056,
#      'level': 6,
#      'xp': 2708,
#      'minionsKilled': 65,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 13160, 'y': 3646},
#      'currentGold': 398,
#      'totalGold': 1948,
#      'level': 6,
#      'xp': 2527,
#      'minionsKilled': 14,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 4992, 'y': 13719},
#      'currentGold': 116,
#      'totalGold': 2516,
#      'level': 6,
#      'xp': 3168,
#      'minionsKilled': 50,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 7339, 'y': 11106},
#      'currentGold': 1170,
#      'totalGold': 2795,
#      'level': 6,
#      'xp': 3142,
#      'minionsKilled': 9,
#      'jungleMinionsKilled': 48,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 7637, 'y': 7524},
#      'currentGold': 711,
#      'totalGold': 3061,
#      'level': 8,
#      'xp': 4147,
#      'minionsKilled': 63,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 13450, 'y': 4326},
#      'currentGold': 686,
#      'totalGold': 2611,
#      'level': 5,
#      'xp': 2326,
#      'minionsKilled': 62,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13396, 'y': 4464},
#      'currentGold': 177,
#      'totalGold': 1827,
#      'level': 5,
#      'xp': 2199,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_KILL',
#      'timestamp': 484859,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 10},
#     {'type': 'WARD_PLACED',
#      'timestamp': 485352,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 1},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 485904,
#      'participantId': 2,
#      'itemId': 3117},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 488120,
#      'participantId': 2,
#      'itemId': 3133},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 488459,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 489072,
#      'participantId': 2,
#      'afterId': 0,
#      'beforeId': 3133},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 490501,
#      'participantId': 2,
#      'itemId': 3751},
#     {'type': 'CHAMPION_KILL',
# ...
#      'timestamp': 1145644,
#      'participantId': 2,
#      'itemId': 3211},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1145644,
#      'participantId': 2,
#      'itemId': 3067},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1146572,
#      'participantId': 6,
#      'itemId': 1026},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1150197,
#      'participantId': 3,
#      'itemId': 3364},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1150197,
#      'participantId': 3,
#      'itemId': 3340},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 1150523,
#      'participantId': 6,
#      'afterId': 0,
#      'beforeId': 1026},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1150988,
#      'participantId': 6,
#      'itemId': 3057},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1151560,
#      'participantId': 6,
#      'itemId': 3113},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1151560,
#      'participantId': 6,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1152578,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1157440,
#      'participantId': 1,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ELITE_MONSTER_KILL',
#      'timestamp': 1162937,
#      'position': {'x': 9866, 'y': 4414},
#      'killerId': 7,
#      'monsterType': 'DRAGON',
#      'monsterSubType': 'WATER_DRAGON'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1164214,
#      'participantId': 10,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1166673,
#      'participantId': 8,
#      'itemId': 3802},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1166673,
#      'participantId': 8,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1172687,
#      'participantId': 10,
#      'itemId': 1043},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1172687,
#      'participantId': 10,
#      'itemId': 1042},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1172687,
#      'participantId': 10,
#      'itemId': 1042},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1172934,
#      'participantId': 10,
#      'itemId': 1037},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1179821,
#      'participantId': 9,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1180353,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1180548,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1180832,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1188322,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 6},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1191073,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 5}],
#    'timestamp': 1200449},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 11083, 'y': 4591},
#      'currentGold': 607,
#      'totalGold': 8555,
#      'level': 13,
#      'xp': 11287,
#      'minionsKilled': 136,
#      'jungleMinionsKilled': 8,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 8697, 'y': 5378},
#      'currentGold': 419,
#      'totalGold': 6994,
#      'level': 11,
#      'xp': 7989,
#      'minionsKilled': 41,
#      'jungleMinionsKilled': 60,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 394, 'y': 461},
#      'currentGold': 1275,
#      'totalGold': 4600,
#      'level': 10,
#      'xp': 6369,
#      'minionsKilled': 73,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 8592, 'y': 4543},
#      'currentGold': 1066,
#      'totalGold': 7411,
#      'level': 10,
#      'xp': 6821,
#      'minionsKilled': 150,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 7835, 'y': 5913},
#      'currentGold': 651,
#      'totalGold': 5276,
#      'level': 10,
#      'xp': 6673,
#      'minionsKilled': 36,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 9905, 'y': 6527},
#      'currentGold': 820,
#      'totalGold': 7320,
#      'level': 12,
#      'xp': 9947,
#      'minionsKilled': 140,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 7841, 'y': 9486},
#      'currentGold': 227,
#      'totalGold': 7892,
#      'level': 12,
#      'xp': 8803,
#      'minionsKilled': 27,
#      'jungleMinionsKilled': 109,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 9753, 'y': 6392},
#      'currentGold': 1186,
#      'totalGold': 8236,
#      'level': 13,
#      'xp': 11251,
#      'minionsKilled': 169,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 12468, 'y': 7252},
#      'currentGold': 434,
#      'totalGold': 7534,
#      'level': 11,
#      'xp': 7841,
#      'minionsKilled': 160,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 9737, 'y': 6165},
#      'currentGold': 268,
#      'totalGold': 5028,
#      'level': 11,
#      'xp': 7309,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_PLACED',
#      'timestamp': 1202464,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 1},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1207320,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 9},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1207320,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'WARD_KILL',
#      'timestamp': 1208877,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 6},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1212160,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1216961,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 9},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1216961,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1217694,
#      'participantId': 7,
#      'itemId': 3211},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1217694,
#      'participantId': 7,
#      'itemId': 1028},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 1219463,
#      'participantId': 7,
#      'afterId': 0,
#      'beforeId': 3211},
#     {'type': 'WARD_KILL',
#      'timestamp': 1219588,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 2},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1220451,
#      'participantId': 7,
#      'itemId': 3067},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1220451,
#      'participantId': 7,
#      'itemId': 1028},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1221824,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 2},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1221824,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'ITEM_SOLD',
#      'timestamp': 1223407,
#      'participantId': 7,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1223630,
#      'participantId': 7,
#      'itemId': 3211},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1225604,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'WARD_KILL',
#      'timestamp': 1226470,
#      'wardType': 'YELLOW_TRINKET',
#      'killerId': 2},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1244989,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1246204,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 1},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1253990,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1256491,
#      'participantId': 7,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1257280,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 1},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1257280,
#      'participantId': 1,
#      'itemId': 2055},
#     {'type': 'WARD_KILL',
#      'timestamp': 1258134,
#      'wardType': 'SIGHT_WARD',
#      'killerId': 8},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1259134,
#      'participantId': 9,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 1260468},
#   {'participantFrames': {'1': {'participantId': 3,
#      'position': {'x': 4668, 'y': 2550},
#      'currentGold': 835,
#      'totalGold': 8782,
#      'level': 14,
#      'xp': 11665,
#      'minionsKilled': 143,
#      'jungleMinionsKilled': 8,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 2,
#      'position': {'x': 4435, 'y': 2242},
#      'currentGold': 142,
#      'totalGold': 7117,
#      'level': 11,
#      'xp': 7989,
#      'minionsKilled': 41,
#      'jungleMinionsKilled': 60,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 4,
#      'position': {'x': 394, 'y': 461},
#      'currentGold': 1397,
#      'totalGold': 4722,
#      'level': 10,
#      'xp': 6369,
#      'minionsKilled': 73,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 5,
#      'position': {'x': 4412, 'y': 2875},
#      'currentGold': 1210,
#      'totalGold': 7555,
#      'level': 10,
#      'xp': 7061,
#      'minionsKilled': 151,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 1,
#      'position': {'x': 4463, 'y': 2068},
#      'currentGold': 542,
#      'totalGold': 5417,
#      'level': 10,
#      'xp': 6752,
#      'minionsKilled': 36,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 8,
#      'position': {'x': 4328, 'y': 3915},
#      'currentGold': 1224,
#      'totalGold': 7724,
#      'level': 13,
#      'xp': 10352,
#      'minionsKilled': 144,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 7,
#      'position': {'x': 4532, 'y': 2445},
#      'currentGold': 585,
#      'totalGold': 8250,
#      'level': 12,
#      'xp': 9410,
#      'minionsKilled': 29,
#      'jungleMinionsKilled': 116,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 6,
#      'position': {'x': 4228, 'y': 3943},
#      'currentGold': 2009,
#      'totalGold': 9059,
#      'level': 14,
#      'xp': 11618,
#      'minionsKilled': 172,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 10,
#      'position': {'x': 4339, 'y': 3834},
#      'currentGold': 1138,
#      'totalGold': 8238,
#      'level': 11,
#      'xp': 8495,
#      'minionsKilled': 167,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 5083, 'y': 3007},
#      'currentGold': 710,
#      'totalGold': 5470,
#      'level': 11,
#      'xp': 7797,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1272440,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1274642,
#      'position': {'x': 9840, 'y': 4337},
#      'killerId': 6,
#      'victimId': 2,
#      'assistingParticipantIds': [8, 10, 9]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1275891,
#      'participantId': 8,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_KILL',
#      'timestamp': 1277858,
#      'wardType': 'YELLOW_TRINKET',
#      'killerId': 7},
#     {'type': 'WARD_KILL',
#      'timestamp': 1281834,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 10},
#     {'type': 'WARD_KILL',
#      'timestamp': 1283425,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 7},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1286799,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 7},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1286799,
#      'participantId': 7,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1289639,
#      'participantId': 6,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1290230,
#      'participantId': 1,
#      'itemId': 3024},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1290230,
#      'participantId': 1,
#      'itemId': 1027},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1290230,
#      'participantId': 1,
#      'itemId': 1029},
#     {'type': 'BUILDING_KILL',
#      'timestamp': 1300684,
#      'position': {'x': 5048, 'y': 4812},
#      'killerId': 8,
#      'assistingParticipantIds': [6, 10, 9],
#      'teamId': 100,
#      'buildingType': 'TOWER_BUILDING',
#      'laneType': 'MID_LANE',
#      'towerType': 'INNER_TURRET'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1302258,
#      'participantId': 9,
#      'itemId': 3851},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1310955,
#      'participantId': 2,
#      'itemId': 1028},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1313190,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1314831,
#      'position': {'x': 4412, 'y': 2875},
#      'killerId': 6,
#      'victimId': 5,
#      'assistingParticipantIds': [8, 10, 9]}],
#    'timestamp': 1320491},
#   {'participantFrames': {'1': {'participantId': 3,
#      'currentGold': 838,
#      'totalGold': 8816,
#      'level': 14,
#      'xp': 11665,
#      'minionsKilled': 143,
#      'jungleMinionsKilled': 8},
#     '2': {'participantId': 2,
#      'currentGold': 175,
#      'totalGold': 7150,
#      'level': 11,
#      'xp': 7989,
#      'minionsKilled': 41,
#      'jungleMinionsKilled': 60},
#     '3': {'participantId': 4,
#      'currentGold': 1431,
#      'totalGold': 4756,
#      'level': 10,
#      'xp': 6369,
#      'minionsKilled': 73,
#      'jungleMinionsKilled': 0},
#     '4': {'participantId': 5,
#      'currentGold': 1064,
#      'totalGold': 7589,
#      'level': 10,
#      'xp': 7061,
#      'minionsKilled': 151,
#      'jungleMinionsKilled': 0},
#     '5': {'participantId': 1,
#      'currentGold': 580,
#      'totalGold': 5455,
#      'level': 10,
#      'xp': 6752,
#      'minionsKilled': 36,
#      'jungleMinionsKilled': 0},
#     '6': {'participantId': 8,
#      'currentGold': 1389,
#      'totalGold': 7889,
#      'level': 13,
#      'xp': 10600,
#      'minionsKilled': 144,
#      'jungleMinionsKilled': 0},
#     '7': {'participantId': 7,
#      'currentGold': 759,
#      'totalGold': 8484,
#      'level': 12,
#      'xp': 9835,
#      'minionsKilled': 29,
#      'jungleMinionsKilled': 116},
#     '8': {'participantId': 6,
#      'currentGold': 2449,
#      'totalGold': 9499,
#      'level': 14,
#      'xp': 11929,
#      'minionsKilled': 172,
#      'jungleMinionsKilled': 16},
#     '9': {'participantId': 10,
#      'currentGold': 1846,
#      'totalGold': 8946,
#      'level': 12,
#      'xp': 8837,
#      'minionsKilled': 167,
#      'jungleMinionsKilled': 4},
#     '10': {'participantId': 9,
#      'currentGold': 949,
#      'totalGold': 5709,
#      'level': 11,
#      'xp': 8314,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0}},
#    'events': [{'type': 'CHAMPION_KILL',
#      'timestamp': 1326764,
#      'position': {'x': 4417, 'y': 2306},
#      'killerId': 10,
#      'victimId': 3,
#      'assistingParticipantIds': [8, 7, 6, 9]},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1329441,
#      'position': {'x': 3826, 'y': 3310},
#      'killerId': 10,
#      'victimId': 2,
#      'assistingParticipantIds': [8, 7, 6, 9]},
#     {'type': 'BUILDING_KILL',
#      'timestamp': 1330573,
#      'position': {'x': 3651, 'y': 3696},
#      'killerId': 0,
#      'assistingParticipantIds': [8, 6],
#      'teamId': 100,
#      'buildingType': 'TOWER_BUILDING',
#      'laneType': 'MID_LANE',
#      'towerType': 'BASE_TURRET'},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1331771,
#      'position': {'x': 3298, 'y': 1460},
#      'killerId': 6,
#      'victimId': 1,
#      'assistingParticipantIds': [7, 9]}],
#    'timestamp': 1380491}],
#  'frameInterval': 60000}
