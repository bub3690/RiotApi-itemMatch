# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로 이 클래스는 RIOT API를 불러오기만 하고,
    파싱 클래스는 opponentsParser 이용
    
    """
    url='https://kr.api.riotgames.com'
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    query_queue="?queue=420"
    #timeline url
    
    
    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["accountId"]
    

    def get_summoner_raw(self,summoner_name):
            #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                        RiotApi.url_summoner_v4+
                        summoner_name+
                        RiotApi.query+self._apikey).json()
        return summoner_data
    
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byAccountid(self,account_id):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        
        ## 추가. 05.11. queryparameter를 추가하여, queue가 420 (rank 5vs5 만 가져온다.)
        ## 추가. 05.11. match중 lane="NONE"은 다시하기 게임이라서 제외함.
        
        account_id=str(account_id)

        print(RiotApi.url+RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey)
        
        game_data=requests.get(RiotApi.url+
                            RiotApi.url_match_v4_accountid
                            +account_id
                            +self.query_queue
                            +RiotApi.query2
                            +self._apikey).json()
        print(game_data)
        matches=[]
        for match in game_data["matches"]:
            if match["lane"]!="NONE" :
                matches.append(match['gameId'])
        return matches
    
    def get_match_byMatchid(self,match_id):
        """
        print(RiotApi.url+RiotApi.url_match_v4_matchid
                            +match_id
                            +RiotApi.query
                            +self._apikey)
        """
        return requests.get(RiotApi.url+RiotApi.url_match_v4_matchid
                            +match_id
                            +RiotApi.query
                            +self._apikey).json()
    
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="RGAPI-f7922aa7-1787-4f61-be99-432393122bc2")
    #print(test.get_league(1))
    #user_accountId=test.get_summoner('종버버버')
    #user_accountId='anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4'
    #games_ids=test.get_gameid_byAccountid(user_accountId)
    match_info = test.get_match_byMatchid('4052319398')#match_v4 test
    
    
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    
    
    
    #print(test.get_league('1').json())
    
    #games_data
    
#games_ids
#match_info
#print(len(games_ids))
#test_timeline
#games_ids
# Out:
# RiotApi init
# {'gameId': 4052319398,
#  'platformId': 'KR',
#  'gameCreation': 1577554592890,
#  'gameDuration': 1336,
#  'queueId': 420,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '9.24.300.6382',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': False,
#    'firstRiftHerald': True,
#    'towerKills': 2,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'vilemawKills': 0,
#    'riftHeraldKills': 1,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 523, 'pickTurn': 1},
#     {'championId': 64, 'pickTurn': 2},
#     {'championId': 555, 'pickTurn': 3},
#     {'championId': 89, 'pickTurn': 4},
#     {'championId': 7, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': True,
#    'firstRiftHerald': False,
#    'towerKills': 5,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 2,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 157, 'pickTurn': 6},
#     {'championId': 412, 'pickTurn': 7},
#     {'championId': 89, 'pickTurn': 8},
#     {'championId': 2, 'pickTurn': 9},
#     {'championId': 60, 'pickTurn': 10}]}],
#  'participants': [{'participantId': 1,
#    'teamId': 100,
#    'championId': 53,
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'participantId': 1,
#     'win': False,
#     'item0': 3855,
#     'item1': 3117,
#     'item2': 3024,
#     'item3': 3109,
#     'item4': 2055,
#     'item5': 0,
#     'item6': 3364,
#     'kills': 2,
#     'deaths': 4,
#     'assists': 3,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 693,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 19582,
#     'magicDamageDealt': 6272,
#     'physicalDamageDealt': 8124,
#     'trueDamageDealt': 5185,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 5669,
#     'magicDamageDealtToChampions': 3632,
#     'physicalDamageDealtToChampions': 1529,
#     'trueDamageDealtToChampions': 508,
#     'totalHeal': 622,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 9115,
#     'damageDealtToObjectives': 370,
#     'damageDealtToTurrets': 370,
#     'visionScore': 24,
#     'timeCCingOthers': 27,
#     'totalDamageTaken': 12292,
#     'magicalDamageTaken': 6945,
#     'physicalDamageTaken': 4819,
#     'trueDamageTaken': 527,
#     'goldEarned': 5455,
#     'goldSpent': 4875,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 36,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 67,
#     'champLevel': 10,
#     'visionWardsBoughtInGame': 5,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 12,
#     'wardsKilled': 5,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8439,
#     'perk0Var1': 218,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8446,
#     'perk1Var1': 279,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8429,
#     'perk2Var1': 55,
#     'perk2Var2': 16,
#     'perk2Var3': 11,
#     'perk3': 8451,
#     'perk3Var1': 131,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8347,
#     'perk4Var1': 0,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8345,
#     'perk5Var1': 3,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8300,
#     'statPerk0': 5007,
#     'statPerk1': 5002,
#     'statPerk2': 5001},
#    'timeline': {'participantId': 1,
#     'creepsPerMinDeltas': {'10-20': 2.1, '0-10': 1.5},
#     'xpPerMinDeltas': {'10-20': 351.2, '0-10': 300.20000000000005},
#     'goldPerMinDeltas': {'10-20': 283.6, '0-10': 180},
#     'csDiffPerMinDeltas': {'10-20': -0.2999999999999998,
#      '0-10': 0.8999999999999999},
#     'xpDiffPerMinDeltas': {'10-20': -132.70000000000005,
#      '0-10': 41.50000000000003},
#     'damageTakenPerMinDeltas': {'10-20': 631.2, '0-10': 252.1},
#     'damageTakenDiffPerMinDeltas': {'10-20': 205.64999999999998,
#      '0-10': 41.64999999999996},
#     'role': 'DUO_SUPPORT',
#     'lane': 'BOTTOM'}},
#   {'participantId': 2,
#    'teamId': 100,
#    'championId': 106,
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'participantId': 2,
#     'win': False,
#     'item0': 1401,
#     'item1': 2031,
#     'item2': 3117,
#     'item3': 3065,
#     'item4': 1028,
#     'item5': 0,
#     'item6': 3364,
#     'kills': 3,
#     'deaths': 4,
#     'assists': 3,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 684,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 88579,
#     'magicDamageDealt': 38666,
#     'physicalDamageDealt': 40130,
#     'trueDamageDealt': 9781,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 8032,
#     'magicDamageDealtToChampions': 3665,
#     'physicalDamageDealtToChampions': 2877,
#     'trueDamageDealtToChampions': 1490,
#     'totalHeal': 4002,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 12792,
#     'damageDealtToObjectives': 7425,
#     'damageDealtToTurrets': 1006,
#     'visionScore': 18,
#     'timeCCingOthers': 22,
#     'totalDamageTaken': 22356,
#     'magicalDamageTaken': 10955,
#     'physicalDamageTaken': 10943,
#     'trueDamageTaken': 458,
#     'goldEarned': 7150,
#     'goldSpent': 6975,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 41,
#     'neutralMinionsKilled': 60,
#     'neutralMinionsKilledTeamJungle': 47,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 667,
#     'champLevel': 11,
#     'visionWardsBoughtInGame': 3,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 6,
#     'wardsKilled': 3,
#     'firstBloodKill': True,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8437,
#     'perk0Var1': 366,
#     'perk0Var2': 265,
#     'perk0Var3': 0,
#     'perk1': 8446,
#     'perk1Var1': 485,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8444,
#     'perk2Var1': 743,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8451,
#     'perk3Var1': 146,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8143,
#     'perk4Var1': 45,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8105,
#     'perk5Var1': 13,
#     'perk5Var2': 4,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5002,
#     'statPerk2': 5001},
#    'timeline': {'participantId': 2,
#     'creepsPerMinDeltas': {'10-20': 2.9, '0-10': 1},
#     'xpPerMinDeltas': {'10-20': 486.4, '0-10': 284.4},
#     'goldPerMinDeltas': {'10-20': 357, '0-10': 266.20000000000005},
#     'damageTakenPerMinDeltas': {'10-20': 1193.8, '0-10': 421},
#     'role': 'NONE',
#     'lane': 'JUNGLE'}},
#   {'participantId': 3,
#    'teamId': 100,
#    'championId': 114,
#    'spell1Id': 4,
#    'spell2Id': 12,
#    'stats': {'participantId': 3,
#     'win': False,
#     'item0': 2033,
#     'item1': 3077,
#     'item2': 1057,
#     'item3': 1054,
#     'item4': 3078,
#     'item5': 3111,
#     'item6': 3364,
#     'kills': 3,
#     'deaths': 3,
#     'assists': 3,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 636,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 104967,
#     'magicDamageDealt': 2235,
#     'physicalDamageDealt': 91814,
#     'trueDamageDealt': 10918,
#     'largestCriticalStrike': 337,
#     'totalDamageDealtToChampions': 11215,
#     'magicDamageDealtToChampions': 1311,
#     'physicalDamageDealtToChampions': 6960,
#     'trueDamageDealtToChampions': 2942,
#     'totalHeal': 5438,
#     'totalUnitsHealed': 5,
#     'damageSelfMitigated': 13540,
#     'damageDealtToObjectives': 12929,
#     'damageDealtToTurrets': 4994,
#     'visionScore': 6,
#     'timeCCingOthers': 7,
#     'totalDamageTaken': 21642,
#     'magicalDamageTaken': 13103,
#     'physicalDamageTaken': 7122,
#     'trueDamageTaken': 1416,
#     'goldEarned': 8816,
#     'goldSpent': 7978,
#     'turretKills': 2,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 143,
#     'neutralMinionsKilled': 8,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 203,
#     'champLevel': 14,
#     'visionWardsBoughtInGame': 2,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 2,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': True,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8437,
#     'perk0Var1': 733,
#     'perk0Var2': 554,
#     'perk0Var3': 0,
#     'perk1': 8446,
#     'perk1Var1': 1503,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8444,
#     'perk2Var1': 1190,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8451,
#     'perk3Var1': 172,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 9104,
#     'perk4Var1': 15,
#     'perk4Var2': 10,
#     'perk4Var3': 0,
#     'perk5': 9111,
#     'perk5Var1': 671,
#     'perk5Var2': 120,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8000,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 3,
#     'creepsPerMinDeltas': {'10-20': 7.4, '0-10': 5.800000000000001},
#     'xpPerMinDeltas': {'10-20': 626.5999999999999, '0-10': 478.5},
#     'goldPerMinDeltas': {'10-20': 473.3, '0-10': 313},
#     'damageTakenPerMinDeltas': {'10-20': 1201.8, '0-10': 628.3},
#     'role': 'SOLO',
#     'lane': 'TOP'}},
#   {'participantId': 4,
#    'teamId': 100,
#    'championId': 84,
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'participantId': 4,
#     'win': False,
#     'item0': 2003,
#     'item1': 3144,
#     'item2': 1054,
#     'item3': 3145,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3340,
#     'kills': 0,
#     'deaths': 3,
#     'assists': 2,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 401,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 22529,
#     'magicDamageDealt': 13276,
#     'physicalDamageDealt': 8956,
#     'trueDamageDealt': 296,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 2945,
#     'magicDamageDealtToChampions': 1397,
#     'physicalDamageDealtToChampions': 1252,
#     'trueDamageDealtToChampions': 296,
#     'totalHeal': 380,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 3292,
#     'damageDealtToObjectives': 109,
#     'damageDealtToTurrets': 0,
#     'visionScore': 4,
#     'timeCCingOthers': 0,
#     'totalDamageTaken': 7198,
#     'magicalDamageTaken': 5473,
#     'physicalDamageTaken': 1135,
#     'trueDamageTaken': 590,
#     'goldEarned': 4756,
#     'goldSpent': 3325,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 73,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 19,
#     'champLevel': 10,
#     'visionWardsBoughtInGame': 1,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 4,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 145,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8009,
#     'perk1Var1': 40,
#     'perk1Var2': 20,
#     'perk1Var3': 0,
#     'perk2': 9105,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 25,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8139,
#     'perk4Var1': 240,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 112,
#     'perk5Var2': 1,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 4,
#     'creepsPerMinDeltas': {'10-20': 2.2, '0-10': 5.1},
#     'xpPerMinDeltas': {'10-20': 205.9, '0-10': 431},
#     'goldPerMinDeltas': {'10-20': 193.4, '0-10': 204.3},
#     'csDiffPerMinDeltas': {'10-20': -6.1, '0-10': -2.400000000000001},
#     'xpDiffPerMinDeltas': {'10-20': -394.1, '0-10': -40.80000000000001},
#     'damageTakenPerMinDeltas': {'10-20': 326.8, '0-10': 393},
#     'damageTakenDiffPerMinDeltas': {'10-20': -264.4,
#      '0-10': 273.59999999999997},
#     'role': 'SOLO',
#     'lane': 'MIDDLE'}},
#   {'participantId': 5,
#    'teamId': 100,
#    'championId': 145,
#    'spell1Id': 7,
#    'spell2Id': 4,
#    'stats': {'participantId': 5,
#     'win': False,
#     'item0': 3006,
#     'item1': 2424,
#     'item2': 2031,
#     'item3': 1055,
#     'item4': 1043,
#     'item5': 3095,
#     'item6': 3340,
#     'kills': 3,
#     'deaths': 4,
#     'assists': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 665,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 63940,
#     'magicDamageDealt': 6460,
#     'physicalDamageDealt': 57480,
#     'trueDamageDealt': 0,
#     'largestCriticalStrike': 281,
#     'totalDamageDealtToChampions': 6843,
#     'magicDamageDealtToChampions': 1943,
#     'physicalDamageDealtToChampions': 4899,
#     'trueDamageDealtToChampions': 0,
#     'totalHeal': 1998,
#     'totalUnitsHealed': 3,
#     'damageSelfMitigated': 5313,
#     'damageDealtToObjectives': 1585,
#     'damageDealtToTurrets': 1585,
#     'visionScore': 16,
#     'timeCCingOthers': 0,
#     'totalDamageTaken': 11390,
#     'magicalDamageTaken': 4937,
#     'physicalDamageTaken': 6104,
#     'trueDamageTaken': 348,
#     'goldEarned': 7589,
#     'goldSpent': 6525,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 151,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 8,
#     'champLevel': 10,
#     'visionWardsBoughtInGame': 1,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 7,
#     'wardsKilled': 2,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8005,
#     'perk0Var1': 360,
#     'perk0Var2': 258,
#     'perk0Var3': 101,
#     'perk1': 9111,
#     'perk1Var1': 140,
#     'perk1Var2': 60,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 20,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 147,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8313,
#     'perk4Var1': 0,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8345,
#     'perk5Var1': 3,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8300,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 5,
#     'creepsPerMinDeltas': {'10-20': 6.2, '0-10': 7.6},
#     'xpPerMinDeltas': {'10-20': 313.1, '0-10': 318.3},
#     'goldPerMinDeltas': {'10-20': 327, '0-10': 324},
#     'csDiffPerMinDeltas': {'10-20': -0.2999999999999998,
#      '0-10': 0.8999999999999999},
#     'xpDiffPerMinDeltas': {'10-20': -132.70000000000005,
#      '0-10': 41.50000000000003},
#     'damageTakenPerMinDeltas': {'10-20': 645.9, '0-10': 294.8},
#     'damageTakenDiffPerMinDeltas': {'10-20': 205.64999999999998,
#      '0-10': 41.64999999999996},
#     'role': 'DUO_CARRY',
#     'lane': 'BOTTOM'}},
#   {'participantId': 6,
#    'teamId': 200,
#    'championId': 112,
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'participantId': 6,
#     'win': True,
#     'item0': 3198,
#     'item1': 1056,
#     'item2': 2033,
#     'item3': 3020,
#     'item4': 3057,
#     'item5': 3113,
#     'item6': 3340,
#     'kills': 7,
#     'deaths': 3,
#     'assists': 3,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'killingSprees': 2,
#     'longestTimeSpentLiving': 606,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 114895,
#     'magicDamageDealt': 103062,
#     'physicalDamageDealt': 8594,
#     'trueDamageDealt': 3239,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 16615,
#     'magicDamageDealtToChampions': 15324,
#     'physicalDamageDealtToChampions': 525,
#     'trueDamageDealtToChampions': 766,
#     'totalHeal': 392,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 5862,
#     'damageDealtToObjectives': 2585,
#     'damageDealtToTurrets': 2585,
#     'visionScore': 19,
#     'timeCCingOthers': 18,
#     'totalDamageTaken': 7434,
#     'magicalDamageTaken': 2257,
#     'physicalDamageTaken': 4352,
#     'trueDamageTaken': 824,
#     'goldEarned': 9499,
#     'goldSpent': 7050,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 172,
#     'neutralMinionsKilled': 16,
#     'neutralMinionsKilledTeamJungle': 12,
#     'neutralMinionsKilledEnemyJungle': 4,
#     'totalTimeCrowdControlDealt': 276,
#     'champLevel': 14,
#     'visionWardsBoughtInGame': 2,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 8,
#     'wardsKilled': 4,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8214,
#     'perk0Var1': 1153,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 510,
#     'perk1Var3': 0,
#     'perk2': 8210,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8237,
#     'perk3Var1': 516,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8345,
#     'perk4Var1': 3,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8352,
#     'perk5Var1': 123,
#     'perk5Var2': 378,
#     'perk5Var3': 401,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8300,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 6,
#     'creepsPerMinDeltas': {'10-20': 8.3, '0-10': 7.5},
#     'xpPerMinDeltas': {'10-20': 600, '0-10': 471.8},
#     'goldPerMinDeltas': {'10-20': 440.3, '0-10': 301.3},
#     'csDiffPerMinDeltas': {'10-20': 6.1, '0-10': 2.400000000000001},
#     'xpDiffPerMinDeltas': {'10-20': 394.1, '0-10': 40.80000000000001},
#     'damageTakenPerMinDeltas': {'10-20': 591.2, '0-10': 119.4},
#     'damageTakenDiffPerMinDeltas': {'10-20': 264.4,
#      '0-10': -273.59999999999997},
#     'role': 'SOLO',
#     'lane': 'MIDDLE'}},
#   {'participantId': 7,
#    'teamId': 200,
#    'championId': 154,
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'participantId': 7,
#     'win': True,
#     'item0': 0,
#     'item1': 3067,
#     'item2': 3211,
#     'item3': 3083,
#     'item4': 1401,
#     'item5': 2422,
#     'item6': 3364,
#     'kills': 4,
#     'deaths': 1,
#     'assists': 7,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 992,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 116473,
#     'magicDamageDealt': 84501,
#     'physicalDamageDealt': 26154,
#     'trueDamageDealt': 5817,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 10344,
#     'magicDamageDealtToChampions': 7707,
#     'physicalDamageDealtToChampions': 1191,
#     'trueDamageDealtToChampions': 1444,
#     'totalHeal': 28919,
#     'totalUnitsHealed': 4,
#     'damageSelfMitigated': 13548,
#     'damageDealtToObjectives': 6478,
#     'damageDealtToTurrets': 0,
#     'visionScore': 21,
#     'timeCCingOthers': 27,
#     'totalDamageTaken': 24430,
#     'magicalDamageTaken': 5420,
#     'physicalDamageTaken': 15290,
#     'trueDamageTaken': 3719,
#     'goldEarned': 8484,
#     'goldSpent': 7725,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 29,
#     'neutralMinionsKilled': 116,
#     'neutralMinionsKilledTeamJungle': 87,
#     'neutralMinionsKilledEnemyJungle': 5,
#     'totalTimeCrowdControlDealt': 448,
#     'champLevel': 12,
#     'visionWardsBoughtInGame': 3,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 5,
#     'wardsKilled': 4,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8439,
#     'perk0Var1': 506,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8463,
#     'perk1Var1': 705,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8429,
#     'perk2Var1': 55,
#     'perk2Var2': 13,
#     'perk2Var3': 13,
#     'perk3': 8453,
#     'perk3Var1': 1850,
#     'perk3Var2': 135,
#     'perk3Var3': 0,
#     'perk4': 8304,
#     'perk4Var1': 10,
#     'perk4Var2': 3,
#     'perk4Var3': 0,
#     'perk5': 8347,
#     'perk5Var1': 0,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8300,
#     'statPerk0': 5007,
#     'statPerk1': 5002,
#     'statPerk2': 5001},
#    'timeline': {'participantId': 7,
#     'creepsPerMinDeltas': {'10-20': 1.6, '0-10': 1.1},
#     'xpPerMinDeltas': {'10-20': 456.8, '0-10': 378.5},
#     'goldPerMinDeltas': {'10-20': 436.3, '0-10': 267.7},
#     'damageTakenPerMinDeltas': {'10-20': 1211.1, '0-10': 683.3},
#     'role': 'NONE',
#     'lane': 'JUNGLE'}},
#   {'participantId': 8,
#    'teamId': 200,
#    'championId': 74,
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'participantId': 8,
#     'win': True,
#     'item0': 1056,
#     'item1': 3165,
#     'item2': 1029,
#     'item3': 3020,
#     'item4': 1029,
#     'item5': 3802,
#     'item6': 3364,
#     'kills': 2,
#     'deaths': 4,
#     'assists': 4,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 288,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 83544,
#     'magicDamageDealt': 69909,
#     'physicalDamageDealt': 10459,
#     'trueDamageDealt': 3175,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 14246,
#     'magicDamageDealtToChampions': 12035,
#     'physicalDamageDealtToChampions': 1421,
#     'trueDamageDealtToChampions': 790,
#     'totalHeal': 1037,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 4428,
#     'damageDealtToObjectives': 3174,
#     'damageDealtToTurrets': 3174,
#     'visionScore': 9,
#     'timeCCingOthers': 19,
#     'totalDamageTaken': 9753,
#     'magicalDamageTaken': 2015,
#     'physicalDamageTaken': 7119,
#     'trueDamageTaken': 617,
#     'goldEarned': 7889,
#     'goldSpent': 6500,
#     'turretKills': 2,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 144,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 135,
#     'champLevel': 13,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 4,
#     'wardsKilled': 1,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8229,
#     'perk0Var1': 1104,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 203,
#     'perk1Var3': 0,
#     'perk2': 8210,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8236,
#     'perk3Var1': 24,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8139,
#     'perk4Var1': 696,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 650,
#     'perk5Var2': 3,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 8,
#     'creepsPerMinDeltas': {'10-20': 7.6, '0-10': 5.3},
#     'xpPerMinDeltas': {'10-20': 579.6, '0-10': 362.20000000000005},
#     'goldPerMinDeltas': {'10-20': 419.2, '0-10': 223.8},
#     'damageTakenPerMinDeltas': {'10-20': 453.5, '0-10': 466.20000000000005},
#     'role': 'NONE',
#     'lane': 'JUNGLE'}},
#   {'participantId': 9,
#    'teamId': 200,
#    'championId': 117,
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'participantId': 9,
#     'win': True,
#     'item0': 3853,
#     'item1': 0,
#     'item2': 0,
#     'item3': 3504,
#     'item4': 1052,
#     'item5': 3117,
#     'item6': 3364,
#     'kills': 0,
#     'deaths': 0,
#     'assists': 11,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 0,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 13251,
#     'magicDamageDealt': 9546,
#     'physicalDamageDealt': 3184,
#     'trueDamageDealt': 521,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 4922,
#     'magicDamageDealtToChampions': 3293,
#     'physicalDamageDealtToChampions': 1107,
#     'trueDamageDealtToChampions': 521,
#     'totalHeal': 617,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 2927,
#     'damageDealtToObjectives': 1623,
#     'damageDealtToTurrets': 624,
#     'visionScore': 36,
#     'timeCCingOthers': 18,
#     'totalDamageTaken': 5324,
#     'magicalDamageTaken': 2076,
#     'physicalDamageTaken': 3008,
#     'trueDamageTaken': 240,
#     'goldEarned': 5709,
#     'goldSpent': 4760,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 10,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 157,
#     'champLevel': 11,
#     'visionWardsBoughtInGame': 5,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 18,
#     'wardsKilled': 3,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8214,
#     'perk0Var1': 424,
#     'perk0Var2': 956,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 265,
#     'perk1Var3': 0,
#     'perk2': 8210,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8237,
#     'perk3Var1': 202,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8345,
#     'perk4Var1': 3,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8347,
#     'perk5Var1': 0,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8300,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 9,
#     'creepsPerMinDeltas': {'10-20': 0.30000000000000004, '0-10': 0.7},
#     'xpPerMinDeltas': {'10-20': 437.70000000000005, '0-10': 291.6},
#     'goldPerMinDeltas': {'10-20': 276.1, '0-10': 162.7},
#     'csDiffPerMinDeltas': {'10-20': 0.2999999999999998,
#      '0-10': -0.8999999999999999},
#     'xpDiffPerMinDeltas': {'10-20': 132.70000000000005,
#      '0-10': -41.50000000000003},
#     'damageTakenPerMinDeltas': {'10-20': 285.8, '0-10': 128.1},
#     'damageTakenDiffPerMinDeltas': {'10-20': -205.64999999999998,
#      '0-10': -41.64999999999996},
#     'role': 'DUO_SUPPORT',
#     'lane': 'BOTTOM'}},
#   {'participantId': 10,
#    'teamId': 200,
#    'championId': 110,
#    'spell1Id': 7,
#    'spell2Id': 4,
#    'stats': {'participantId': 10,
#     'win': True,
#     'item0': 3153,
#     'item1': 1055,
#     'item2': 3006,
#     'item3': 1043,
#     'item4': 1037,
#     'item5': 2055,
#     'item6': 3340,
#     'kills': 5,
#     'deaths': 3,
#     'assists': 2,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 397,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 92710,
#     'magicDamageDealt': 9941,
#     'physicalDamageDealt': 82695,
#     'trueDamageDealt': 74,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 11105,
#     'magicDamageDealtToChampions': 2707,
#     'physicalDamageDealtToChampions': 8323,
#     'trueDamageDealtToChampions': 74,
#     'totalHeal': 945,
#     'totalUnitsHealed': 2,
#     'damageSelfMitigated': 4173,
#     'damageDealtToObjectives': 10031,
#     'damageDealtToTurrets': 4617,
#     'visionScore': 17,
#     'timeCCingOthers': 19,
#     'totalDamageTaken': 9755,
#     'magicalDamageTaken': 2801,
#     'physicalDamageTaken': 6861,
#     'trueDamageTaken': 92,
#     'goldEarned': 8946,
#     'goldSpent': 7100,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 167,
#     'neutralMinionsKilled': 4,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 225,
#     'champLevel': 12,
#     'visionWardsBoughtInGame': 3,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 9,
#     'wardsKilled': 4,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8008,
#     'perk0Var1': 1,
#     'perk0Var2': 50,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 83,
#     'perk1Var2': 140,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 18,
#     'perk2Var2': 30,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 357,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8226,
#     'perk4Var1': 250,
#     'perk4Var2': 437,
#     'perk4Var3': 0,
#     'perk5': 8237,
#     'perk5Var1': 338,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8200,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5001},
#    'timeline': {'participantId': 10,
#     'creepsPerMinDeltas': {'10-20': 8.6, '0-10': 6.6},
#     'xpPerMinDeltas': {'10-20': 492, '0-10': 243.9},
#     'goldPerMinDeltas': {'10-20': 440.7, '0-10': 230.3},
#     'csDiffPerMinDeltas': {'10-20': 0.2999999999999998,
#      '0-10': -0.8999999999999999},
#     'xpDiffPerMinDeltas': {'10-20': 132.70000000000005,
#      '0-10': -41.50000000000003},
#     'damageTakenPerMinDeltas': {'10-20': 580, '0-10': 335.5},
#     'damageTakenDiffPerMinDeltas': {'10-20': -205.64999999999998,
#      '0-10': -41.64999999999996},
#     'role': 'DUO_CARRY',
#     'lane': 'BOTTOM'}}],
#  'participantIdentities': [{'participantId': 1,
#    'player': {'platformId': 'KR',
#     'accountId': 'XW9bfU01H-4Kqy4zCp8oo5BWeRZ2ia1sjAByU3mQcGSivFk',
#     'summonerName': 'CantStopDying',
#     'summonerId': 'lKyH-cALwauhSW-kY1ZI7me_V3GE7eSvsH79RNtYmAlC8nk',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'XW9bfU01H-4Kqy4zCp8oo5BWeRZ2ia1sjAByU3mQcGSivFk',
#     'matchHistoryUri': '/v1/stats/player_history/KR/206915580',
#     'profileIcon': 3555}},
#   {'participantId': 2,
#    'player': {'platformId': 'KR',
#     'accountId': 'anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4',
#     'summonerName': '종버버버',
#     'summonerId': '3_PzfARZ1fOK5NEKAA6o711Wdr5_usC4uKqZMmhlE_z7EA',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4',
#     'matchHistoryUri': '/v1/stats/player_history/KR/3810915',
#     'profileIcon': 6}},
#   {'participantId': 3,
#    'player': {'platformId': 'KR',
#     'accountId': 'p_Hq-phD7bjByUDMBTBN9aZ6NfJHBMR-9Y1IIY3Q-g9dSMI',
#     'summonerName': '의정부커터칼',
#     'summonerId': 'QA6TwGCeLeHZ7Y7vMmmrAdoHFSPK3fKbj6jPU0QyKfemrqs',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'p_Hq-phD7bjByUDMBTBN9aZ6NfJHBMR-9Y1IIY3Q-g9dSMI',
#     'matchHistoryUri': '/v1/stats/player_history/KR/200137251',
#     'profileIcon': 3221}},
#   {'participantId': 4,
#    'player': {'platformId': 'KR',
#     'accountId': 'sI5nSu-YNLVg8EJjo47asucXIESPhKoS_bdlBtWbNEYy',
#     'summonerName': '소울앤필',
#     'summonerId': 'glzZNNhwZr59-VkLg9IZECowhQ4uxxUUYa0ZM_ECnDsSSQ',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'sI5nSu-YNLVg8EJjo47asucXIESPhKoS_bdlBtWbNEYy',
#     'matchHistoryUri': '/v1/stats/player_history/KR/2003524',
#     'profileIcon': 518}},
#   {'participantId': 5,
#    'player': {'platformId': 'KR',
#     'accountId': 'L7eVqbvPya6bKzlVC1yfIumLrdFY7dRyNjwpCvlw48vF',
#     'summonerName': '조콰세연',
#     'summonerId': 'wnMncEaZauiojGyFjSLRZY9mbzwaf2xAKRvbcsYp3mZ7dZE',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'L7eVqbvPya6bKzlVC1yfIumLrdFY7dRyNjwpCvlw48vF',
#     'matchHistoryUri': '/v1/stats/player_history/KR/6742106',
#     'profileIcon': 3186}},
#   {'participantId': 6,
#    'player': {'platformId': 'KR',
#     'accountId': '9Lxf857oCkXgNXe2nW0LJGK7W9QlM3e2pIbTuDxmITY2wSA',
#     'summonerName': '레이저쟁이',
#     'summonerId': 'P4AN_XKy-UdOMYHg_BT-WhhiI4zyLJKHwezenp0Zjr6BHVo',
#     'currentPlatformId': 'KR',
#     'currentAccountId': '9Lxf857oCkXgNXe2nW0LJGK7W9QlM3e2pIbTuDxmITY2wSA',
#     'matchHistoryUri': '/v1/stats/player_history/KR/200198224',
#     'profileIcon': 4270}},
#   {'participantId': 7,
#    'player': {'platformId': 'KR',
#     'accountId': 'vlI2UHXBm8rKk2yQ9Usuj2s9HC6OnnLweEEKZz0WU8S-',
#     'summonerName': '치와왈',
#     'summonerId': 'TWDPFZjgBpog56g4ZkeS5hSFMX0QO25ozyplNRAiej5Sgw',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'vlI2UHXBm8rKk2yQ9Usuj2s9HC6OnnLweEEKZz0WU8S-',
#     'matchHistoryUri': '/v1/stats/player_history/KR/2538578',
#     'profileIcon': 3556}},
#   {'participantId': 8,
#    'player': {'platformId': 'KR',
#     'accountId': 'ocpUvZ4uhv3mxH41WUGQvwA6E25AmSjX6O_b3aK4_N37',
#     'summonerName': '만월의천사',
#     'summonerId': 'g8aDo2ZWOQGdTEmoZAjXhNKVQwRWAxr3T-YKavUIQyhZ-A',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'ocpUvZ4uhv3mxH41WUGQvwA6E25AmSjX6O_b3aK4_N37',
#     'matchHistoryUri': '/v1/stats/player_history/KR/3089715',
#     'profileIcon': 3175}},
#   {'participantId': 9,
#    'player': {'platformId': 'KR',
#     'accountId': 'p9kGoauEN1hEXDG6lkGs98DPvRhuwCP8sTKM2EwmsFqrVX4',
#     'summonerName': '민수띠',
#     'summonerId': 'Bv7z3mJ6phV_Y2lO407DlLXI7EK_a2zI3X7e57uDID-6cQE',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'p9kGoauEN1hEXDG6lkGs98DPvRhuwCP8sTKM2EwmsFqrVX4',
#     'matchHistoryUri': '/v1/stats/player_history/KR/204100901',
#     'profileIcon': 1298}},
#   {'participantId': 10,
#    'player': {'platformId': 'KR',
#     'accountId': 'dxL6l5YdH68sbeOjqfInLOq431yzxUu4jK11EHOG-4ZV',
#     'summonerName': '네E버',
#     'summonerId': '5_zyHNhdDigcvnWN9DPaFEsPKs6cTmTLHn3bJ56KutTUGHU',
#     'currentPlatformId': 'KR',
#     'currentAccountId': 'dxL6l5YdH68sbeOjqfInLOq431yzxUu4jK11EHOG-4ZV',
#     'matchHistoryUri': '/v1/stats/player_history/KR/7807425',
#     'profileIcon': 3588}}]}
