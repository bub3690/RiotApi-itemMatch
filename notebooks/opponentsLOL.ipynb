# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로는 이 클래스는 RIOT API를 불러오기만 하고,
    차후 파싱 클래스를 따로 만들예정.
    """
    url='https://kr.api.riotgames.com'
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    #timeline url
    
    
    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["accountId"]
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byAccountid(self,account_id):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        account_id=str(account_id)
        print(RiotApi.url+
                            RiotApi.url_match_v4_accountid+
                            account_id+
                            RiotApi.query
                            +self._apikey)
        game_data=requests.get(RiotApi.url+
                            RiotApi.url_match_v4_accountid+
                            account_id+
                            RiotApi.query
                            +self._apikey).json()
        print(game_data)
        matches=[]
        for match in game_data["matches"]:
            matches.append(match['gameId'])

        return matches
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="RGAPI-1db9d2d1-76ed-4991-9162-471b0b0cd030")
    print(test.get_league(1))
    #user_accountId=test.get_summoner('종버버버')
    #user_accountId='anXYP4yARxqIKeKuBd6F9FFDVQhPs-wr7uTZ4IE6NJp4'
    #games_ids=test.get_gameid_byAccountid(user_accountId)
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    
    
    
    #print(test.get_league('1').json())
    
    #games_data
    
#games_ids
#test_timeline
#games_ids
# Out:
# RiotApi init
# [{'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '40fxr2xcapc4Xwj7nQ9mm_reqOySyusv99CjCuekyQl4akTAGHyEr1g7LQ', 'summonerName': '에이미 리아', 'leaguePoints': 627, 'wins': 272, 'losses': 215, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '23x5GTkJ4qevxMpP2LaSQM1SHfwj2LDx7wt3rMnnaubmaxMb', 'summonerName': 'SIHYE0N', 'leaguePoints': 616, 'wins': 79, 'losses': 54, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '6ntC-sXFIBYyHEuSY9-69i5lvDn5JRry5764qQgLqVVyLHBBoDPo5waq6g', 'summonerName': 'imD1pig', 'leaguePoints': 607, 'wins': 312, 'losses': 280, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'l0NPlyc3fMYY5by8wegJ3KQfYRyaNIlRIeLIHfeiiFP8eom8gyEHNAXAfQ', 'summonerName': 'langmanbusi', 'leaguePoints': 598, 'wins': 103, 'losses': 53, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '3NPS06m0pxE8Ortbf4AX-idvHin0Oh6RLQycxi3MdXP3h_Tx6YRig0UbZA', 'summonerName': 'cvxnblkwerio', 'leaguePoints': 594, 'wins': 75, 'losses': 50, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'pJCnxlT6IqaHgDLr78Q2yRvQzYs0dyGjPDevVu7x1BoTZv0', 'summonerName': 'Shadow Swamp', 'leaguePoints': 590, 'wins': 279, 'losses': 234, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'wZBA9megCYxbq08dfEqE31AKn5khFUOV081zolIHb0oy6A', 'summonerName': '미쳐놈', 'leaguePoints': 587, 'wins': 347, 'losses': 318, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'Wc5Sv2Ltfh5SmNf5Teh9IIazciRwngX4e2ucxW9r9Mb52yk', 'summonerName': 'KaiSamira', 'leaguePoints': 585, 'wins': 353, 'losses': 318, 'veteran': True, 'inactive': False, 'freshBlood': False, 'hotStreak': True}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': '0Vr61_zMyZQw6pLIjjxKgL3iquJ4gcLNKJRUhXHyxjzvwiqMnqigu_T27g', 'summonerName': 'cxzkdasjdqwoie', 'leaguePoints': 581, 'wins': 177, 'losses': 142, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'ebDmZprxQDcjo9-b3mMfTv8JvgTGBkLXrLopoUjyOFeuLsXTj8dg8qVnrg', 'summonerName': 'wanfeng', 'leaguePoints': 580, 'wins': 107, 'losses': 71, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'PY7wgSq28x4cDtibfBBdV8VvMP6T7Wb1HHzYxiGeNMIivis', 'summonerName': '광명불꽃턱', 'leaguePoints': 579, 'wins': 259, 'losses': 229, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': 'a37af09b-ecb8-3664-9453-cf2b0138dd6e', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'GRANDMASTER', 'rank': 'I', 'summonerId': 'PFCKYbGIyOdmHfgfq_x46ELxtpweBHwIHN1lJh6yiayd- ...
