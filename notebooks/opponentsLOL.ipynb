# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로 이 클래스는 RIOT API를 불러오기만 하고,
    파싱 클래스는 opponentsParser 이용
    
    """
    url='https://kr.api.riotgames.com'
    url_v5='https://asia.api.riotgames.com/lol/match/v5/matches/' #match_v5와 timeline에 사용
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    query_queue="?queue=420"## 랭크 5vs5 게임만 출력위해서 get_gameid_byAccountid 함수에서 사용.
    #timeline url
    
    #timeline -> url_v5+'/KR_'+matchid+'/timeline'+query+api_key
    

    
    
    #puuid : /lol/match/v5/matches/by-puuid/{puuid}/ids
    #match_id: https://asia.api.riotgames.com/lol/match/v5/matches/KR_5173018625?api_key=RGAPI-c186a251-9936-4aa6-8ef3-3e742f274ac2
    #timeline: https://asia.api.riotgames.com/lol/match/v5/matches/KR_5173018625/timeline?api_key=RGAPI-c186a251-9936-4aa6-8ef3-3e742f274ac2

    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return puuid
        #소환사 이름만 입력해주면 작동한다.
        ## 08.11 puuid 출력하는것으로 변경.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["puuid"]
    

    def get_summoner_raw(self,summoner_name):
            #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                        RiotApi.url_summoner_v4+
                        summoner_name+
                        RiotApi.query+self._apikey).json()
        return summoner_data
    
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byPuuid(self,puuid):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        
        ## 추가. 05.11. queryparameter를 추가하여, queue가 420 (rank 5vs5 만 가져온다.)
        ## 추가. 05.11. match중 lane="NONE"은 다시하기 게임이라서 제외함.
        ## 추가. 08.11. match_v5 패치로 get_gameid_byPuuid로 수정.
        
        #match_v5_by_puuid -> url_v5+'/by-puuid/'+puuid+'/ids'+ # puuid로 matchid 캐는것.
        '''
        print(RiotApi.url_v5+'by-puuid/'
                            +puuid
                            +'/ids'
                            +RiotApi.query_queue
                            +RiotApi.query2
                            +self._apikey)
        '''
        
        return requests.get(RiotApi.url_v5+'by-puuid/'
                            +puuid
                            +'/ids'
                            +RiotApi.query_queue
                            +RiotApi.query2
                            +self._apikey).json()
    
    def get_match_byMatchid(self,match_id):
        """
        0810. match_v5 반영
        match_v5_matchid -> url_v5+'KR_'+matchid+query+api_key
        print(RiotApi.url_v5+'KR_'+
                            match_id+
                            RiotApi.query+
                            self._apikey)
        """
        return requests.get(RiotApi.url_v5+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()
#match_v5 -> url_v5+matchid+query+api_key
#timeline -> url_v5+matchid+'/timeline'+query+api_key    
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="")
    #print(test.get_league(1))
    user_puuId=test.get_summoner('Hide on bush')
    #print(test.get_summoner_raw('Hide on bush'))
    #user_puuId='uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA'
    game_ids=test.get_gameid_byPuuid(user_puuId)
    match_info = test.get_match_byMatchid(game_ids[0])#match_v5 test
    #time_line=test.get_timeline_byMatchid('4052319398')
    
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    #RhV9CBcTzyNArJhyiFMXYT-nOt8j4K8_cMjarSPdDscs0VP0_XvM0CFEi2NIgLNWAG7xLGL1G-ndkQ :puuid
    
    
    #print(test.get_league('1').json())
    
    #games_data


#games_ids
match_info
#print(len(games_ids))
#test_timeline
#time_line
# Out:
# RiotApi init
# {'id': 'vkd_PqaJzsrXzwopL9gIS45RamsPN1-cIz4K4JouZCBNiw', 'accountId': 'NQHa08UbpG4iGUhEDcBqLB0dVv_l2AW4r7JKGV9V9LIr', 'puuid': 'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1628331404000, 'summonerLevel': 485}
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_5384501448',
#   'participants': ['4xjlgzfyzS6j8KWbkq4rXwWYXUETH_UHqdF3p_Txa9LiSh3skd1cOEKEuHi8Rmb27LdoZJPeMnRmNA',
#    'otEydz7KMIKCGvfS5xNd0dkiaSYFspOHsKuqUASTavAETQLZjwsknJNwM8Tjxdx2dq6hmauD31_2Xg',
#    '1MhuKRl6QCsFvhpx4M3tCTqWK1D7BQ0-hX_-kh2RehsUuKJagMPmxARnb8JxGSeuMqpPy3Tp2_0CFg',
#    'HrSWCB2Gn1oBHTNlIRaJQ9zGe2-M63RSvU6sPOJfflXfQUI-hmdj21Xit9byecVWHeux84BATzwylw',
#    'dbh2V6rbkNyEGrNJ5OcguXBb5eVHv_s9tK8U78Iooa8CWONQ4dmmJkUmsbmsYORbT6l2PXQDZBJoCw',
#    'Bm0e_JxNGnx4uehiTZR0GMkxBqIgV0ucCAtPYYP3CrlhH9o5-mFkgrWJb4ns03lH7yvuV4R9iEjsGQ',
#    'p2BiXNH7O0fvHy3Rm-s-aM2BsIhDTQWbg9Hv81Bv9cTCGjIxBwbu2Tlo2rvvd0awZkFqhqCIPGyF3Q',
#    'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA',
#    'ra8HkbiRndOTRrX7EagurasLVFsGg6bRidO76A4x-PC_6hfnSuKgmWaBvrZYIN3oJH6NgcXgeNQdpA',
#    'UGnb5JsoXBWJu_hJbSTl-NCF2U8S_aba6ElypDi6nvJlN7bHnX3W0pUH7Q8patp_CrWGy3KpowSsrw']},
#  'info': {'gameCreation': 1628659949000,
#   'gameDuration': 1465315,
#   'gameId': 5384501448,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-5384501448',
#   'gameStartTimestamp': 1628659966025,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '11.16.390.1945',
#   'mapId': 11,
#   'participants': [{'assists': 5,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 11253,
#     'champLevel': 13,
#     'championId': 69,
#     'championName': 'Cassiopeia',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 2481,
#     'damageDealtToObjectives': 8551,
#     'damageDealtToTurrets': 2481,
#     'damageSelfMitigated': 7713,
#     'deaths': 4,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 9375,
#     'goldSpent': 9110,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6656,
#     'item1': 4629,
#     'item2': 1026,
#     'item3': 1052,
#     'item4': 1082,
#     'item5': 1011,
#     'item6': 3363,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 531,
#     'magicDamageDealt': 69462,
#     'magicDamageDealtToChampions': 11371,
#     'magicDamageTaken': 5347,
#     'neutralMinionsKilled': 6,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 167, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 2263, 'var2': 0, 'var3': 0},
#         {'perk': 9105, 'var1': 17, 'var2': 40, 'var3': 0},
#         {'perk': 8299, 'var1': 328, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 602, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1647, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 7374,
#     'physicalDamageDealtToChampions': 511,
#     'physicalDamageTaken': 10876,
#     'profileIcon': 775,
#     'puuid': '4xjlgzfyzS6j8KWbkq4rXwWYXUETH_UHqdF3p_Txa9LiSh3skd1cOEKEuHi8Rmb27LdoZJPeMnRmNA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 92,
#     'spell2Casts': 15,
#     'spell3Casts': 279,
#     'spell4Casts': 8,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': 'HAM7zBOJ3rqye5qFLK9RfWGW1GlmFOHDnINv8kceQyLxUA',
#     'summonerLevel': 444,
#     'summonerName': '킬러톱',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 16,
#     'timePlayed': 1461,
#     'totalDamageDealt': 77199,
#     'totalDamageDealtToChampions': 12244,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16295,
#     'totalHeal': 5257,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 139,
#     'totalTimeCCDealt': 111,
#     'totalTimeSpentDead': 105,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 362,
#     'trueDamageDealtToChampions': 362,
#     'trueDamageTaken': 71,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionScore': 29,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 4,
#     'wardsPlaced': 10,
#     'win': True},
#    {'assists': 10,
#     'baronKills': 1,
#     'bountyLevel': 1,
#     'champExperience': 12087,
#     'champLevel': 14,
#     'championId': 163,
#     'championName': 'Taliyah',
#     'championTransform': 0,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 461,
#     'damageDealtToObjectives': 17801,
#     'damageDealtToTurrets': 461,
#     'damageSelfMitigated': 7712,
#     'deaths': 5,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 0,
#     'dragonKills': 2,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 8849,
#     'goldSpent': 8125,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 0,
#     'item1': 3157,
#     'item2': 3020,
#     'item3': 1082,
#     'item4': 6655,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 17,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 515,
#     'magicDamageDealt': 100577,
#     'magicDamageDealtToChampions': 9649,
#     'magicDamageTaken': 5732,
#     'neutralMinionsKilled': 126,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 779, 'var2': 13, 'var3': 0},
#         {'perk': 8126, 'var1': 478, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2918, 'var2': 4, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8275, 'var1': 17, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 4, 'var2': 10, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 13381,
#     'physicalDamageDealtToChampions': 739,
#     'physicalDamageTaken': 11841,
#     'profileIcon': 1386,
#     'puuid': 'otEydz7KMIKCGvfS5xNd0dkiaSYFspOHsKuqUASTavAETQLZjwsknJNwM8Tjxdx2dq6hmauD31_2Xg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 150,
#     'spell2Casts': 33,
#     'spell3Casts': 57,
#     'spell4Casts': 10,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 13,
#     'summoner2Id': 11,
#     'summonerId': 'xR4FIWfBs-X2jqAt6cm3EIcJFdRpxJen5Nw27b7j6mZ1Xw2mqw75c60LgQ',
#     'summonerLevel': 101,
#     'summonerName': '202135223',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 9,
#     'timePlayed': 1461,
#     'totalDamageDealt': 123580,
#     'totalDamageDealtToChampions': 11777,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 17573,
#     'totalHeal': 7028,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 26,
#     'totalTimeCCDealt': 345,
#     'totalTimeSpentDead': 118,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 9621,
#     'trueDamageDealtToChampions': 1389,
#     'trueDamageTaken': 0,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionScore': 31,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 4,
#     'wardsPlaced': 7,
#     'win': True},
#    {'assists': 6,
#     'baronKills': 0,
#     'bountyLevel': 5,
#     'champExperience': 12573,
#     'champLevel': 14,
#     'championId': 157,
#     'championName': 'Yasuo',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 2440,
#     'damageDealtToObjectives': 15306,
#     'damageDealtToTurrets': 2440,
#     'damageSelfMitigated': 20410,
#     'deaths': 6,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 11544,
#     'goldSpent': 9900,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3006,
#     'item1': 6673,
#     'item2': 3033,
#     'item3': 1038,
#     'item4': 1055,
#     'item5': 1037,
#     'item6': 3364,
#     'itemsPurchased': 21,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 1567,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 300,
#     'magicDamageDealt': 12397,
#     'magicDamageDealtToChampions': 1226,
#     'magicDamageTaken': 3668,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2615, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 783, 'var2': 300, 'var3': 0},
#         {'perk': 9104, 'var1': 15, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 397, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 815, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2542, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 104250,
#     'physicalDamageDealtToChampions': 14679,
#     'physicalDamageTaken': 17772,
#     'profileIcon': 4903,
#     'puuid': '1MhuKRl6QCsFvhpx4M3tCTqWK1D7BQ0-hX_-kh2RehsUuKJagMPmxARnb8JxGSeuMqpPy3Tp2_0CFg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 219,
#     'spell2Casts': 21,
#     'spell3Casts': 145,
#     'spell4Casts': 9,
#     'summoner1Casts': 5,
#     'summoner1Id': 14,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'Z27Zmyz9swx_va1LbtND-VQPLU1DjZSDsNcxsNP6BxHAbok',
#     'summonerLevel': 168,
#     'summonerName': 'hei ye shi zhe',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 24,
#     'timePlayed': 1461,
#     'totalDamageDealt': 122006,
#     'totalDamageDealtToChampions': 18128,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21659,
#     'totalHeal': 7822,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 159,
#     'totalTimeCCDealt': 94,
#     'totalTimeSpentDead': 140,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5358,
#     'trueDamageDealtToChampions': 2223,
#     'trueDamageTaken': 219,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionScore': 20,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 9,
#     'wardsPlaced': 5,
#     'win': True},
#    {'assists': 8,
#     'baronKills': 0,
#     'bountyLevel': 3,
#     'champExperience': 11333,
#     'champLevel': 13,
#     'championId': 523,
#     'championName': 'Aphelios',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 8248,
#     'damageDealtToObjectives': 11762,
#     'damageDealtToTurrets': 8248,
#     'damageSelfMitigated': 7945,
#     'deaths': 1,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 12141,
#     'goldSpent': 10125,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 1038,
#     'item1': 6676,
#     'item2': 6673,
#     'item3': 3006,
#     'item4': 1018,
#     'item5': 1055,
#     'item6': 3363,
#     'itemsPurchased': 16,
#     'killingSprees': 2,
#     'kills': 6,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 554,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1208,
#     'magicDamageDealt': 3259,
#     'magicDamageDealtToChampions': 738,
#     'magicDamageTaken': 3520,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 155, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1706, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 19, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 278, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 524, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1453, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 100479,
#     'physicalDamageDealtToChampions': 12461,
#     'physicalDamageTaken': 7661,
#     'profileIcon': 4762,
#     'puuid': 'HrSWCB2Gn1oBHTNlIRaJQ9zGe2-M63RSvU6sPOJfflXfQUI-hmdj21Xit9byecVWHeux84BATzwylw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 85,
#     'spell2Casts': 272,
#     'spell3Casts': 0,
#     'spell4Casts': 3,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 7,
#     'summonerId': 'AZlE0Oc-AKfuprcITEQZzVWU7l8LuaAtIk1iYxd5DSYiTME',
#     'summonerLevel': 251,
#     'summonerName': 'X1LANX1LANX1LAN',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 18,
#     'timePlayed': 1461,
#     'totalDamageDealt': 105180,
#     'totalDamageDealtToChampions': 14046,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 11409,
#     'totalHeal': 4215,
#     'totalHealsOnTeammates': 630,
#     'totalMinionsKilled': 199,
#     'totalTimeCCDealt': 124,
#     'totalTimeSpentDead': 36,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 1440,
#     'trueDamageDealtToChampions': 846,
#     'trueDamageTaken': 228,
#     'turretKills': 3,
#     'turretTakedowns': 5,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionScore': 27,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 9,
#     'wardsPlaced': 8,
#     'win': True},
#    {'assists': 7,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 8335,
#     'champLevel': 11,
#     'championId': 526,
#     'championName': 'Rell',
#     'championTransform': 0,
#     'consumablesPurchased': 13,
#     'damageDealtToBuildings': 65,
#     'damageDealtToObjectives': 1570,
#     'damageDealtToTurrets': 65,
#     'damageSelfMitigated': 16728,
#     'deaths': 2,
#     'detectorWardsPlaced': 9,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 6527,
#     'goldSpent': 6125,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3860,
#     'item1': 6664,
#     'item2': 3009,
#     'item3': 3067,
#     'item4': 1029,
#     'item5': 2055,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 1,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1064,
#     'magicDamageDealt': 10477,
#     'magicDamageDealtToChampions': 3310,
#     'magicDamageTaken': 2842,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 400, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 813, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 641, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 24, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8306, 'var1': 4, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 3694,
#     'physicalDamageDealtToChampions': 597,
#     'physicalDamageTaken': 7608,
#     'profileIcon': 5023,
#     'puuid': 'dbh2V6rbkNyEGrNJ5OcguXBb5eVHv_s9tK8U78Iooa8CWONQ4dmmJkUmsbmsYORbT6l2PXQDZBJoCw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 27,
#     'spell2Casts': 39,
#     'spell3Casts': 56,
#     'spell4Casts': 5,
#     'summoner1Casts': 8,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 14,
#     'summonerId': 'RJrFPsxkK7TmGZFdAkHpN-K_35CzlaB9bbA54dXp7r0TaZs',
#     'summonerLevel': 235,
#     'summonerName': '농심 마인부우',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 18,
#     'timePlayed': 1461,
#     'totalDamageDealt': 22052,
#     'totalDamageDealtToChampions': 4815,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 10600,
#     'totalHeal': 2002,
#     'totalHealsOnTeammates': 751,
#     'totalMinionsKilled': 31,
#     'totalTimeCCDealt': 44,
#     'totalTimeSpentDead': 68,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 7880,
#     'trueDamageDealtToChampions': 907,
#     'trueDamageTaken': 150,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionScore': 45,
#     'visionWardsBoughtInGame': 11,
#     'wardsKilled': 6,
#     'wardsPlaced': 26,
#     'win': True},
#    {'assists': 5,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 11361,
#     'champLevel': 13,
#     'championId': 64,
#     'championName': 'LeeSin',
#     'championTransform': 0,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 2495,
#     'damageDealtToObjectives': 3342,
#     'damageDealtToTurrets': 2495,
#     'damageSelfMitigated': 12700,
#     'deaths': 5,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 9689,
#     'goldSpent': 9250,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6630,
#     'item1': 2421,
#     'item2': 0,
#     'item3': 3111,
#     'item4': 3053,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 19,
#     'killingSprees': 2,
#     'kills': 5,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 489,
#     'magicDamageDealt': 34855,
#     'magicDamageDealtToChampions': 2567,
#     'magicDamageTaken': 8828,
#     'neutralMinionsKilled': 9,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 129, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 526, 'var2': 200, 'var3': 0},
#         {'perk': 9104, 'var1': 13, 'var2': 20, 'var3': 0},
#         {'perk': 8299, 'var1': 305, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8242, 'var1': 50, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 645, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 68687,
#     'physicalDamageDealtToChampions': 7844,
#     'physicalDamageTaken': 8588,
#     'profileIcon': 21,
#     'puuid': 'Bm0e_JxNGnx4uehiTZR0GMkxBqIgV0ucCAtPYYP3CrlhH9o5-mFkgrWJb4ns03lH7yvuV4R9iEjsGQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 118,
#     'spell2Casts': 97,
#     'spell3Casts': 74,
#     'spell4Casts': 7,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': 'K_I4y8b2blc2dYDNqZc5_2KuoqJGF1h_Vn-jyU_ciaRuOXI',
#     'summonerLevel': 399,
#     'summonerName': 'anyeonghasayo',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 10,
#     'timePlayed': 1461,
#     'totalDamageDealt': 108413,
#     'totalDamageDealtToChampions': 10411,
#     'totalDamageShieldedOnTeammates': 164,
#     'totalDamageTaken': 17926,
#     'totalHeal': 1555,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 176,
#     'totalTimeCCDealt': 165,
#     'totalTimeSpentDead': 123,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4870,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 509,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 5,
#     'wardsPlaced': 12,
#     'win': False},
#    {'assists': 3,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 8921,
#     'champLevel': 12,
#     'championId': 154,
#     'championName': 'Zac',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 10975,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 22514,
#     'deaths': 7,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 8969,
#     'goldSpent': 8750,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6664,
#     'item1': 1082,
#     'item2': 3158,
#     'item3': 4401,
#     'item4': 3067,
#     'item5': 2055,
#     'item6': 3364,
#     'itemsPurchased': 23,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 544,
#     'magicDamageDealt': 84725,
#     'magicDamageDealtToChampions': 8390,
#     'magicDamageTaken': 9735,
#     'neutralMinionsKilled': 102,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 7,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 803, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 402, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 50, 'var2': 15, 'var3': 16},
#         {'perk': 8451, 'var1': 152, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 11, 'var2': 40, 'var3': 0},
#         {'perk': 9111, 'var1': 261, 'var2': 160, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 12865,
#     'physicalDamageDealtToChampions': 776,
#     'physicalDamageTaken': 13904,
#     'profileIcon': 23,
#     'puuid': 'p2BiXNH7O0fvHy3Rm-s-aM2BsIhDTQWbg9Hv81Bv9cTCGjIxBwbu2Tlo2rvvd0awZkFqhqCIPGyF3Q',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 49,
#     'spell2Casts': 148,
#     'spell3Casts': 72,
#     'spell4Casts': 8,
#     'summoner1Casts': 11,
#     'summoner1Id': 11,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'EmyK1TAGYSeECgPMsSuiI0MTxWn94Z-my9yj4DSvGg2Bt9I',
#     'summonerLevel': 186,
#     'summonerName': 'hdfh',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 35,
#     'timePlayed': 1461,
#     'totalDamageDealt': 108782,
#     'totalDamageDealtToChampions': 9955,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27600,
#     'totalHeal': 23384,
#     'totalHealsOnTeammates': 214,
#     'totalMinionsKilled': 29,
#     'totalTimeCCDealt': 424,
#     'totalTimeSpentDead': 199,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 11190,
#     'trueDamageDealtToChampions': 788,
#     'trueDamageTaken': 3959,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 24,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 4,
#     'wardsPlaced': 6,
#     'win': False},
#    {'assists': 6,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 10256,
#     'champLevel': 13,
#     'championId': 236,
#     'championName': 'Lucian',
#     'championTransform': 0,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 2711,
#     'damageDealtToObjectives': 3650,
#     'damageDealtToTurrets': 2711,
#     'damageSelfMitigated': 6217,
#     'deaths': 7,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 10652,
#     'goldSpent': 10230,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6671,
#     'item1': 6694,
#     'item2': 2055,
#     'item3': 1055,
#     'item4': 3133,
#     'item5': 3158,
#     'item6': 3363,
#     'itemsPurchased': 26,
#     'killingSprees': 1,
#     'kills': 7,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 391,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 411,
#     'magicDamageDealt': 4070,
#     'magicDamageDealtToChampions': 1395,
#     'magicDamageTaken': 4760,
#     'neutralMinionsKilled': 9,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 8,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 1599, 'var2': 1061, 'var3': 537},
#         {'perk': 8009, 'var1': 1910, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 19, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 291, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 91040,
#     'physicalDamageDealtToChampions': 17742,
#     'physicalDamageTaken': 10415,
#     'profileIcon': 6,
#     'puuid': 'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 68,
#     'spell2Casts': 38,
#     'spell3Casts': 41,
#     'spell4Casts': 9,
#     'summoner1Casts': 6,
#     'summoner1Id': 3,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'vkd_PqaJzsrXzwopL9gIS45RamsPN1-cIz4K4JouZCBNiw',
#     'summonerLevel': 485,
#     'summonerName': 'Hide on bush',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 6,
#     'timePlayed': 1461,
#     'totalDamageDealt': 95891,
#     'totalDamageDealtToChampions': 19138,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16182,
#     'totalHeal': 1003,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 141,
#     'totalTimeCCDealt': 97,
#     'totalTimeSpentDead': 135,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 780,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 1005,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 16,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 2,
#     'wardsPlaced': 11,
#     'win': False},
#    {'assists': 6,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 10291,
#     'champLevel': 13,
#     'championId': 22,
#     'championName': 'Ashe',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 4017,
#     'damageDealtToObjectives': 11649,
#     'damageDealtToTurrets': 4017,
#     'damageSelfMitigated': 5574,
#     'deaths': 2,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 8658,
#     'goldSpent': 8575,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 2031,
#     'item1': 3091,
#     'item2': 6673,
#     'item3': 1042,
#     'item4': 1042,
#     'item5': 3006,
#     'item6': 3363,
#     'itemsPurchased': 22,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 255,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 1169,
#     'magicDamageDealt': 2096,
#     'magicDamageDealtToChampions': 1692,
#     'magicDamageTaken': 1697,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 47, 'var2': 87, 'var3': 0},
#         {'perk': 8126, 'var1': 427, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 7, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1439, 'var2': 4, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8410, 'var1': 69, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 99061,
#     'physicalDamageDealtToChampions': 7722,
#     'physicalDamageTaken': 8888,
#     'profileIcon': 4793,
#     'puuid': 'ra8HkbiRndOTRrX7EagurasLVFsGg6bRidO76A4x-PC_6hfnSuKgmWaBvrZYIN3oJH6NgcXgeNQdpA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 25,
#     'spell2Casts': 57,
#     'spell3Casts': 10,
#     'spell4Casts': 8,
#     'summoner1Casts': 2,
#     'summoner1Id': 7,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'WCU4sLODk2GxujBgR35VWio1n9aOe2Dy6p-EfIBZaU_fAYA7',
#     'summonerLevel': 263,
#     'summonerName': '평범한 숟가락',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 31,
#     'timePlayed': 1461,
#     'totalDamageDealt': 122613,
#     'totalDamageDealtToChampions': 9790,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 10738,
#     'totalHeal': 2060,
#     'totalHealsOnTeammates': 422,
#     'totalMinionsKilled': 198,
#     'totalTimeCCDealt': 603,
#     'totalTimeSpentDead': 10,
#     'totalUnitsHealed': 2,
#     'tripleKills': 0,
#     'trueDamageDealt': 21455,
#     'trueDamageDealtToChampions': 375,
#     'trueDamageTaken': 152,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 4,
#     'wardsPlaced': 6,
#     'win': False},
#    {'assists': 8,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 7510,
#     'champLevel': 11,
#     'championId': 147,
#     'championName': 'Seraphine',
#     'championTransform': 0,
#     'consumablesPurchased': 10,
#     'damageDealtToBuildings': 256,
#     'damageDealtToObjectives': 704,
#     'damageDealtToTurrets': 256,
#     'damageSelfMitigated': 4727,
#     'deaths': 3,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 6132,
#     'goldSpent': 5750,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3853,
#     'item1': 2065,
#     'item2': 1004,
#     'item3': 3916,
#     'item4': 2055,
#     'item5': 3158,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 608,
#     'magicDamageDealt': 14916,
#     'magicDamageDealtToChampions': 4476,
#     'magicDamageTaken': 2639,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 1484, 'var2': 0, 'var3': 0},
#         {'perk': 8401, 'var1': 173, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 239, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 151, 'var2': 399, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 2114,
#     'physicalDamageDealtToChampions': 907,
#     'physicalDamageTaken': 3442,
#     'profileIcon': 29,
#     'puuid': 'UGnb5JsoXBWJu_hJbSTl-NCF2U8S_aba6ElypDi6nvJlN7bHnX3W0pUH7Q8patp_CrWGy3KpowSsrw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 57,
#     'spell2Casts': 23,
#     'spell3Casts': 31,
#     'spell4Casts': 4,
#     'summoner1Casts': 3,
#     'summoner1Id': 3,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'kh4LGSaWK7jwJtQBp1eh41YwwE9F7W7H0AkBJfHDPUXR8g',
#     'summonerLevel': 305,
#     'summonerName': 'HUYATV XiJinping',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 20,
#     'timePlayed': 1461,
#     'totalDamageDealt': 17031,
#     'totalDamageDealtToChampions': 5383,
#     'totalDamageShieldedOnTeammates': 1793,
#     'totalDamageTaken': 6678,
#     'totalHeal': 936,
#     'totalHealsOnTeammates': 712,
#     'totalMinionsKilled': 14,
#     'totalTimeCCDealt': 112,
#     'totalTimeSpentDead': 84,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 595,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 45,
#     'visionWardsBoughtInGame': 8,
#     'wardsKilled': 5,
#     'wardsPlaced': 24,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 166, 'pickTurn': 1},
#      {'championId': 115, 'pickTurn': 2},
#      {'championId': 131, 'pickTurn': 3},
#      {'championId': 58, 'pickTurn': 4},
#      {'championId': 39, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 24},
#      'dragon': {'first': True, 'kills': 2},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 1},
#      'tower': {'first': False, 'kills': 6}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 412, 'pickTurn': 6},
#      {'championId': 76, 'pickTurn': 7},
#      {'championId': 89, 'pickTurn': 8},
#      {'championId': -1, 'pickTurn': 9},
#      {'championId': -1, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 18},
#      'dragon': {'first': False, 'kills': 1},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': True, 'kills': 3}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}
