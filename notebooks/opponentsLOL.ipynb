# %%
import requests
import pandas
import numpy

class  RiotApi:
    """
    AUTHOR:이종법
    DATE:2021-03-19
    PURPOSE: 라이엇API에서, MATCH-V4 , LEAGUE-EXP-V4 , SUMMONER-V4, 를 불러오는 CLASS
    간단히 말하면, 이 class에서만 requests를 사용한다.
    
    앞으로 이 클래스는 RIOT API를 불러오기만 하고,
    파싱 클래스는 opponentsParser 이용
    
    """
    url='https://kr.api.riotgames.com'
    url_v5='https://asia.api.riotgames.com/lol/match/v5/matches/' #match_v5와 timeline에 사용
    url_summoner_v4 = '/lol/summoner/v4/summoners/by-name/' # + summonername
    url_league_exp_v4='/lol/league-exp/v4/entries/RANKED_SOLO_5x5/GRANDMASTER/I?page='
    #league_exp_v4는 ?page=페이지수&api_key={} 로 요청해야한다.
    #단, 그랜드마스터 한정
    url_match_v4_accountid = '/lol/match/v4/matchlists/by-account/' # + account_id?api_key=
    url_match_v4_matchid = '/lol/match/v4/matches/' # + match_id?api_key=
    url_match_v4_timeline_matchid='/lol/match/v4/timelines/by-match/' # + match_id?api_key=
    query='?api_key='
    query2='&api_key='
    query_queue="?queue=420"## 랭크 5vs5 게임만 출력위해서 get_gameid_byAccountid 함수에서 사용.
    #timeline url
    
    #timeline -> url_v5+'/KR_'+matchid+'/timeline'+query+api_key
    

    
    
    #puuid : /lol/match/v5/matches/by-puuid/{puuid}/ids
    #match_id: https://asia.api.riotgames.com/lol/match/v5/matches/KR_5173018625?api_key=RGAPI-c186a251-9936-4aa6-8ef3-3e742f274ac2
    #timeline: https://asia.api.riotgames.com/lol/match/v5/matches/KR_5173018625/timeline?api_key=RGAPI-c186a251-9936-4aa6-8ef3-3e742f274ac2

    
    
    def __init__(self,apikey,):
        self._apikey=apikey
        print("RiotApi init")
    
    def get_summoner(self,summoner_name):
        #return puuid
        #소환사 이름만 입력해주면 작동한다.
        ## 08.11 puuid 출력하는것으로 변경.
        summoner_data=requests.get(RiotApi.url+
                            RiotApi.url_summoner_v4+
                            summoner_name+
                            RiotApi.query+self._apikey).json()
        print(summoner_data)
        return summoner_data["puuid"]
    

    def get_summoner_raw(self,summoner_name):
            #return account_id
        #소환사 이름만 입력해주면 작동한다.
        summoner_data=requests.get(RiotApi.url+
                        RiotApi.url_summoner_v4+
                        summoner_name+
                        RiotApi.query+self._apikey).json()
        return summoner_data
    
    
    def get_league(self,page):
        page = str(page)
        #페이지만 입력해주면 작동한다.
        return requests.get(RiotApi.url+
                            RiotApi.url_league_exp_v4+
                            page+
                            RiotApi.query2+self._apikey).json()
    
    def get_gameid_byPuuid(self,puuid):
        #return [game_id]
        #game_id는 굉장히 많기때문에 리스트로 출력된다.
        
        #account_id를 받아서, 게임아이디를 출력하기 위해서 사용.
        #match_v4 중 account_id를 받는것 사용.
        
        ## 추가. 05.11. queryparameter를 추가하여, queue가 420 (rank 5vs5 만 가져온다.)
        ## 추가. 05.11. match중 lane="NONE"은 다시하기 게임이라서 제외함.
        ## 추가. 08.11. match_v5 패치로 get_gameid_byPuuid로 수정.
        
        #match_v5_by_puuid -> url_v5+'/by-puuid/'+puuid+'/ids'+ # puuid로 matchid 캐는것.
        '''
        print(RiotApi.url_v5+'by-puuid/'
                            +puuid
                            +'/ids'
                            +RiotApi.query_queue
                            +RiotApi.query2
                            +self._apikey)
        '''
        
        return requests.get(RiotApi.url_v5+'by-puuid/'
                            +puuid
                            +'/ids'
                            +RiotApi.query_queue
                            +RiotApi.query2
                            +self._apikey).json()
    
    def get_match_byMatchid(self,match_id):
        """
        0810. match_v5 반영
        match_v5_matchid -> url_v5+'KR_'+matchid+query+api_key
        print(RiotApi.url_v5+'KR_'+
                            match_id+
                            RiotApi.query+
                            self._apikey)
        """
        return requests.get(RiotApi.url_v5+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()
#match_v5 -> url_v5+matchid+query+api_key
#timeline -> url_v5+matchid+'/timeline'+query+api_key    
    
    def get_timeline_byMatchid(self,match_id):
        return requests.get(RiotApi.url+
                            RiotApi.url_match_v4_timeline_matchid+
                            match_id+
                            RiotApi.query+
                            self._apikey).json()

if __name__ == '__main__':
    #단위테스트
    test = RiotApi(apikey="RGAPI-d30d6558-4b0a-4e37-9bdf-1edfe39ff539")
    #print(test.get_league(1))
    user_puuId=test.get_summoner('Hide on bush')
    #print(test.get_summoner_raw('Hide on bush'))
    #user_puuId='uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA'
    game_ids=test.get_gameid_byPuuid(user_puuId)
    print(game_ids[0])
    match_info = test.get_match_byMatchid('KR_5384630363')#match_v5 test
    #time_line=test.get_timeline_byMatchid('4052319398')
    
    #test_gameId=games_ids[0] # 게임아이디 하나 받아서, timeline 테스트에 사용
    #test_timeline=test.get_timeline_byMatchid(str(test_gameId))
    #RhV9CBcTzyNArJhyiFMXYT-nOt8j4K8_cMjarSPdDscs0VP0_XvM0CFEi2NIgLNWAG7xLGL1G-ndkQ :puuid
    
    
    #print(test.get_league('1').json())
    
    #games_data


#games_ids
match_info
#print(len(games_ids))
#test_timeline
#time_line
# Out:
# RiotApi init
# {'id': 'vkd_PqaJzsrXzwopL9gIS45RamsPN1-cIz4K4JouZCBNiw', 'accountId': 'NQHa08UbpG4iGUhEDcBqLB0dVv_l2AW4r7JKGV9V9LIr', 'puuid': 'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1628331404000, 'summonerLevel': 485}
# KR_5384630363
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_5384630363',
#   'participants': ['h2oBqJmGXtW5wCGt__k0BlwGY_QJ08qpbh_IlCwx64A9TzRiKAdXF7sZkFkn_ld6seoBO7YiGmgPug',
#    'cz-fSCnQQoayNAJHjHvVAddvJ9j5IQ8ZlSCc3fUUYvh6mfV3CjT8WHneTc805G_79qCwFlhPxtirtg',
#    'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA',
#    '9IT3qfMw6J0UwQfxFUkKxA_mNh4GqmGx4d7u1rbVPrQujUH8X2Lvsb8InMNo3uIWf-7iWTBR3xqC0A',
#    'PJRvet-bsecM2wSRPjdWx4LGwGd6AYW0K_rpJYKtl5jLpc28F9cJHqwVUvcRw7ce7QIJIMHljGS3aQ',
#    '0IIt_DwStTMEu1CAPpHO7EjKfQ_hoQX1ugTj6ZMiQDqWTf_Hqyy_UDhW5WrP3eXQSertkGhYUPUerg',
#    'bABySOfJl5iDOzMS3QnfL7kBhpV7gImIcFxVIECETOPPGmKbuR3YjLGj2ZylCnshexMd1Dbse2Z4sA',
#    '_avw7prIhugVMQ8BgKVWjPCdjY1TYAuQIsLKPqwQ7hzC42tYM38vHseELMTWRDMxRYg65WeZVm61bg',
#    '0lTZ5Qb99lDz0jpKVO58pm1ML_3muXWlZRqvePY-PJwHfwif2ZtnssmlqZF9Ek2ssCRy3ogrXWK6CQ',
#    '3nn7InPfsJVU3_oP9FQb5eITYfwkV6kAzJezQsKDDSuUcz5hVnjW3WNkCXdgejVa4lQvWI0y--3UZQ']},
#  'info': {'gameCreation': 1628663864000,
#   'gameDuration': 966759,
#   'gameId': 5384630363,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-5384630363',
#   'gameStartTimestamp': 1628663880652,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '11.16.390.1945',
#   'mapId': 11,
#   'participants': [{'assists': 5,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 8168,
#     'champLevel': 11,
#     'championId': 117,
#     'championName': 'Lulu',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 447,
#     'damageDealtToObjectives': 816,
#     'damageDealtToTurrets': 447,
#     'damageSelfMitigated': 3742,
#     'deaths': 1,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 5562,
#     'goldSpent': 4775,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3011,
#     'item1': 1028,
#     'item2': 2033,
#     'item3': 0,
#     'item4': 3158,
#     'item5': 3070,
#     'item6': 3340,
#     'itemsPurchased': 11,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 715,
#     'magicDamageDealt': 36966,
#     'magicDamageDealtToChampions': 6852,
#     'magicDamageTaken': 1347,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 604, 'var2': 77, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 416, 'var3': 0},
#         {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 289, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8352, 'var1': 177, 'var2': 887, 'var3': 663}],
#        'style': 8300}]},
#     'physicalDamageDealt': 10082,
#     'physicalDamageDealtToChampions': 1584,
#     'physicalDamageTaken': 4867,
#     'profileIcon': 4784,
#     'puuid': 'h2oBqJmGXtW5wCGt__k0BlwGY_QJ08qpbh_IlCwx64A9TzRiKAdXF7sZkFkn_ld6seoBO7YiGmgPug',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 69,
#     'spell2Casts': 18,
#     'spell3Casts': 30,
#     'spell4Casts': 6,
#     'summoner1Casts': 2,
#     'summoner1Id': 12,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'BhJhyo-JrfO1E9n5pNRIa_OUOoUf3ilQuF6YIYEGrGjcDoOX',
#     'summonerLevel': 284,
#     'summonerName': 'Fiora',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 16,
#     'timePlayed': 965,
#     'totalDamageDealt': 49434,
#     'totalDamageDealtToChampions': 8436,
#     'totalDamageShieldedOnTeammates': 208,
#     'totalDamageTaken': 6215,
#     'totalHeal': 880,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 107,
#     'totalTimeCCDealt': 336,
#     'totalTimeSpentDead': 30,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2385,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 0,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 2,
#     'wardsPlaced': 8,
#     'win': True},
#    {'assists': 3,
#     'baronKills': 0,
#     'bountyLevel': 3,
#     'champExperience': 7102,
#     'champLevel': 10,
#     'championId': 2,
#     'championName': 'Olaf',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 1433,
#     'damageDealtToObjectives': 25904,
#     'damageDealtToTurrets': 1433,
#     'damageSelfMitigated': 8151,
#     'deaths': 1,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 1,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 7467,
#     'goldSpent': 7200,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6630,
#     'item1': 2055,
#     'item2': 3044,
#     'item3': 3047,
#     'item4': 1037,
#     'item5': 1028,
#     'item6': 3364,
#     'itemsPurchased': 16,
#     'killingSprees': 2,
#     'kills': 5,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 682,
#     'magicDamageDealt': 5230,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 3812,
#     'neutralMinionsKilled': 100,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 268, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 766, 'var2': 160, 'var3': 0},
#         {'perk': 9104, 'var1': 12, 'var2': 20, 'var3': 0},
#         {'perk': 8299, 'var1': 260, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 73688,
#     'physicalDamageDealtToChampions': 4674,
#     'physicalDamageTaken': 9717,
#     'profileIcon': 4903,
#     'puuid': 'cz-fSCnQQoayNAJHjHvVAddvJ9j5IQ8ZlSCc3fUUYvh6mfV3CjT8WHneTc805G_79qCwFlhPxtirtg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 121,
#     'spell2Casts': 27,
#     'spell3Casts': 50,
#     'spell4Casts': 3,
#     'summoner1Casts': 12,
#     'summoner1Id': 11,
#     'summoner2Casts': 4,
#     'summoner2Id': 6,
#     'summonerId': 'J9v7QkD0Yu94nlwHJy6CMKqvfs4lx4pzKykN6mAXuZ0sOmGHYb5odAFqiw',
#     'summonerLevel': 91,
#     'summonerName': 'stupid yekai',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 4,
#     'timePlayed': 965,
#     'totalDamageDealt': 101586,
#     'totalDamageDealtToChampions': 6228,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 14032,
#     'totalHeal': 7736,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 12,
#     'totalTimeCCDealt': 336,
#     'totalTimeSpentDead': 27,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 22666,
#     'trueDamageDealtToChampions': 1554,
#     'trueDamageTaken': 501,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 0,
#     'wardsPlaced': 4,
#     'win': True},
#    {'assists': 4,
#     'baronKills': 0,
#     'bountyLevel': 8,
#     'champExperience': 8155,
#     'champLevel': 11,
#     'championId': 7,
#     'championName': 'Leblanc',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 568,
#     'damageDealtToObjectives': 4030,
#     'damageDealtToTurrets': 568,
#     'damageSelfMitigated': 3359,
#     'deaths': 0,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 7994,
#     'goldSpent': 6200,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 2033,
#     'item1': 3111,
#     'item2': 0,
#     'item3': 1082,
#     'item4': 3108,
#     'item5': 6655,
#     'item6': 3364,
#     'itemsPurchased': 10,
#     'killingSprees': 1,
#     'kills': 8,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 8,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 0,
#     'magicDamageDealt': 33198,
#     'magicDamageDealtToChampions': 8017,
#     'magicDamageTaken': 2664,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1021, 'var2': 0, 'var3': 0},
#         {'perk': 8139, 'var1': 569, 'var2': 0, 'var3': 0},
#         {'perk': 8136, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 954, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8352, 'var1': 197, 'var2': 1155, 'var3': 888}],
#        'style': 8300}]},
#     'physicalDamageDealt': 11771,
#     'physicalDamageDealtToChampions': 1984,
#     'physicalDamageTaken': 5027,
#     'profileIcon': 6,
#     'puuid': 'uqy66cXvaNu5cUS7nGRvKXRFyX9kSu3vptCijcNBO9hKVUXNaagQ5PYCYSuvItgBAaPXs_svQZrtkA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 56,
#     'spell2Casts': 94,
#     'spell3Casts': 24,
#     'spell4Casts': 13,
#     'summoner1Casts': 2,
#     'summoner1Id': 12,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': 'vkd_PqaJzsrXzwopL9gIS45RamsPN1-cIz4K4JouZCBNiw',
#     'summonerLevel': 485,
#     'summonerName': 'Hide on bush',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 5,
#     'timePlayed': 965,
#     'totalDamageDealt': 47051,
#     'totalDamageDealtToChampions': 10342,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 7739,
#     'totalHeal': 2594,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 96,
#     'totalTimeCCDealt': 41,
#     'totalTimeSpentDead': 0,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2081,
#     'trueDamageDealtToChampions': 340,
#     'trueDamageTaken': 48,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionScore': 9,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 0,
#     'wardsPlaced': 5,
#     'win': True},
#    {'assists': 7,
#     'baronKills': 0,
#     'bountyLevel': 1,
#     'champExperience': 6412,
#     'champLevel': 10,
#     'championId': 81,
#     'championName': 'Ezreal',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 2382,
#     'damageDealtToObjectives': 2382,
#     'damageDealtToTurrets': 2382,
#     'damageSelfMitigated': 1915,
#     'deaths': 1,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 6474,
#     'goldSpent': 5875,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3067,
#     'item1': 1036,
#     'item2': 0,
#     'item3': 3158,
#     'item4': 3057,
#     'item5': 3042,
#     'item6': 3363,
#     'itemsPurchased': 17,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 420,
#     'magicDamageDealt': 4788,
#     'magicDamageDealtToChampions': 2926,
#     'magicDamageTaken': 1019,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1909, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 157, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 58483,
#     'physicalDamageDealtToChampions': 4995,
#     'physicalDamageTaken': 3888,
#     'profileIcon': 26,
#     'puuid': '9IT3qfMw6J0UwQfxFUkKxA_mNh4GqmGx4d7u1rbVPrQujUH8X2Lvsb8InMNo3uIWf-7iWTBR3xqC0A',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 156,
#     'spell2Casts': 17,
#     'spell3Casts': 15,
#     'spell4Casts': 5,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 7,
#     'summonerId': 'fkReX77s6oV1MXi60tYe8hxB4PmVeRI-Iv7sX975jDjy4-n1aGnjWhTzDQ',
#     'summonerLevel': 126,
#     'summonerName': 'calmdownnbro',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 0,
#     'timePlayed': 965,
#     'totalDamageDealt': 67832,
#     'totalDamageDealtToChampions': 7922,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 5011,
#     'totalHeal': 543,
#     'totalHealsOnTeammates': 270,
#     'totalMinionsKilled': 142,
#     'totalTimeCCDealt': 0,
#     'totalTimeSpentDead': 14,
#     'totalUnitsHealed': 2,
#     'tripleKills': 0,
#     'trueDamageDealt': 4560,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 104,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionScore': 10,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 7,
#     'win': True},
#    {'assists': 4,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 4182,
#     'champLevel': 8,
#     'championId': 16,
#     'championName': 'Soraka',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 712,
#     'damageDealtToObjectives': 712,
#     'damageDealtToTurrets': 712,
#     'damageSelfMitigated': 2847,
#     'deaths': 2,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 4161,
#     'goldSpent': 3660,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3853,
#     'item1': 2031,
#     'item2': 0,
#     'item3': 3158,
#     'item4': 4642,
#     'item5': 3067,
#     'item6': 3364,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 497,
#     'magicDamageDealt': 9918,
#     'magicDamageDealtToChampions': 2515,
#     'magicDamageTaken': 1488,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 530, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 150, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 180, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 409, 'var2': 34, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 2711,
#     'physicalDamageDealtToChampions': 479,
#     'physicalDamageTaken': 3683,
#     'profileIcon': 4783,
#     'puuid': 'PJRvet-bsecM2wSRPjdWx4LGwGd6AYW0K_rpJYKtl5jLpc28F9cJHqwVUvcRw7ce7QIJIMHljGS3aQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 56,
#     'spell2Casts': 15,
#     'spell3Casts': 11,
#     'spell4Casts': 2,
#     'summoner1Casts': 1,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 3,
#     'summonerId': 'dthmillyID-diJ3-RNkb8UzN3jhqjH8cOeI1cJB80jKjzks',
#     'summonerLevel': 161,
#     'summonerName': '더블큐티준서버거',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 16,
#     'timePlayed': 965,
#     'totalDamageDealt': 12630,
#     'totalDamageDealtToChampions': 2994,
#     'totalDamageShieldedOnTeammates': 366,
#     'totalDamageTaken': 5319,
#     'totalHeal': 3559,
#     'totalHealsOnTeammates': 2425,
#     'totalMinionsKilled': 9,
#     'totalTimeCCDealt': 135,
#     'totalTimeSpentDead': 30,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 147,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionScore': 25,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 3,
#     'wardsPlaced': 15,
#     'win': True},
#    {'assists': 0,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 6679,
#     'champLevel': 10,
#     'championId': 39,
#     'championName': 'Irelia',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 1745,
#     'damageDealtToObjectives': 1745,
#     'damageDealtToTurrets': 1745,
#     'damageSelfMitigated': 6542,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 6069,
#     'goldSpent': 5825,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 1054,
#     'item1': 2031,
#     'item2': 3111,
#     'item3': 3153,
#     'item4': 1083,
#     'item5': 1036,
#     'item6': 3363,
#     'itemsPurchased': 14,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 391,
#     'magicDamageDealt': 7265,
#     'magicDamageDealtToChampions': 1417,
#     'magicDamageTaken': 7380,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 48, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 338, 'var2': 0, 'var3': 0},
#         {'perk': 9105, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 240, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 464, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 58, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 51560,
#     'physicalDamageDealtToChampions': 4061,
#     'physicalDamageTaken': 5127,
#     'profileIcon': 4931,
#     'puuid': '0IIt_DwStTMEu1CAPpHO7EjKfQ_hoQX1ugTj6ZMiQDqWTf_Hqyy_UDhW5WrP3eXQSertkGhYUPUerg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 138,
#     'spell2Casts': 8,
#     'spell3Casts': 21,
#     'spell4Casts': 2,
#     'summoner1Casts': 2,
#     'summoner1Id': 12,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'IWlCN5ppuLGWUzoCZnEQU-aBQRNYNTm07Q4j5Dh9YFpZyA',
#     'summonerLevel': 631,
#     'summonerName': '화이팅 이현',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 5,
#     'timePlayed': 965,
#     'totalDamageDealt': 58826,
#     'totalDamageDealtToChampions': 5479,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 12576,
#     'totalHeal': 1666,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 128,
#     'totalTimeCCDealt': 20,
#     'totalTimeSpentDead': 121,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 68,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 7,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 4,
#     'win': False},
#    {'assists': 1,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 5745,
#     'champLevel': 9,
#     'championId': 106,
#     'championName': 'Volibear',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 78,
#     'damageDealtToObjectives': 6487,
#     'damageDealtToTurrets': 78,
#     'damageSelfMitigated': 10556,
#     'deaths': 3,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 5303,
#     'goldSpent': 4325,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 2031,
#     'item1': 0,
#     'item2': 1001,
#     'item3': 6632,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 12,
#     'killingSprees': 1,
#     'kills': 2,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 680,
#     'magicDamageDealt': 30469,
#     'magicDamageDealtToChampions': 1051,
#     'magicDamageTaken': 3105,
#     'neutralMinionsKilled': 80,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 7,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 394, 'var2': 209, 'var3': 185},
#         {'perk': 9111, 'var1': 156, 'var2': 60, 'var3': 0},
#         {'perk': 9105, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 148, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8275, 'var1': 9, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 2, 'var2': 40, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 37038,
#     'physicalDamageDealtToChampions': 2399,
#     'physicalDamageTaken': 9410,
#     'profileIcon': 1596,
#     'puuid': 'bABySOfJl5iDOzMS3QnfL7kBhpV7gImIcFxVIECETOPPGmKbuR3YjLGj2ZylCnshexMd1Dbse2Z4sA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 34,
#     'spell2Casts': 77,
#     'spell3Casts': 36,
#     'spell4Casts': 2,
#     'summoner1Casts': 1,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 11,
#     'summonerId': 'UTL-RXLy0rI6wRBbpIwqLRzEbGUlyShkTHdAIUsWNa78ULg0V_WoYOgAJg',
#     'summonerLevel': 118,
#     'summonerName': 'wybaby',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 6,
#     'timePlayed': 965,
#     'totalDamageDealt': 71352,
#     'totalDamageDealtToChampions': 3905,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 13384,
#     'totalHeal': 5162,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 20,
#     'totalTimeCCDealt': 300,
#     'totalTimeSpentDead': 76,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3844,
#     'trueDamageDealtToChampions': 454,
#     'trueDamageTaken': 869,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 15,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 3,
#     'wardsPlaced': 3,
#     'win': False},
#    {'assists': 1,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 6465,
#     'champLevel': 10,
#     'championId': 134,
#     'championName': 'Syndra',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 253,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 3228,
#     'deaths': 2,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 4693,
#     'goldSpent': 4150,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 2033,
#     'item1': 3802,
#     'item2': 1056,
#     'item3': 1026,
#     'item4': 0,
#     'item5': 3020,
#     'item6': 3340,
#     'itemsPurchased': 8,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 672,
#     'magicDamageDealt': 35969,
#     'magicDamageDealtToChampions': 3615,
#     'magicDamageTaken': 5167,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 8,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 387, 'var2': 0, 'var3': 0},
#         {'perk': 8139, 'var1': 395, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 2, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 84, 'var2': 1, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8352, 'var1': 220, 'var2': 1450, 'var3': 1099}],
#        'style': 8300}]},
#     'physicalDamageDealt': 9747,
#     'physicalDamageDealtToChampions': 957,
#     'physicalDamageTaken': 2850,
#     'profileIcon': 1114,
#     'puuid': '_avw7prIhugVMQ8BgKVWjPCdjY1TYAuQIsLKPqwQ7hzC42tYM38vHseELMTWRDMxRYg65WeZVm61bg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 78,
#     'spell2Casts': 42,
#     'spell3Casts': 18,
#     'spell4Casts': 2,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 2,
#     'summoner2Id': 12,
#     'summonerId': 'wKdCOmiaavwXFzZsxp5mE2MsEwn5fNbZMZNrqhtOAmzSFlriWaAi1mtZOA',
#     'summonerLevel': 54,
#     'summonerName': 'Decimation',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 9,
#     'timePlayed': 965,
#     'totalDamageDealt': 45717,
#     'totalDamageDealtToChampions': 4572,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 8422,
#     'totalHeal': 2208,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 118,
#     'totalTimeCCDealt': 121,
#     'totalTimeSpentDead': 55,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 404,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 4,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 4,
#     'win': False},
#    {'assists': 2,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 5490,
#     'champLevel': 9,
#     'championId': 22,
#     'championName': 'Ashe',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 1353,
#     'damageDealtToObjectives': 1353,
#     'damageDealtToTurrets': 1353,
#     'damageSelfMitigated': 2719,
#     'deaths': 2,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 6041,
#     'goldSpent': 5225,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 1055,
#     'item1': 6673,
#     'item2': 2031,
#     'item3': 0,
#     'item4': 0,
#     'item5': 3006,
#     'item6': 3340,
#     'itemsPurchased': 9,
#     'killingSprees': 1,
#     'kills': 2,
#     'lane': 'NONE',
#     'largestCriticalStrike': 182,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 700,
#     'magicDamageDealt': 574,
#     'magicDamageDealtToChampions': 174,
#     'magicDamageTaken': 2717,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 1, 'var2': 10, 'var3': 0},
#         {'perk': 8009, 'var1': 560, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 60, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8410, 'var1': 55, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 45355,
#     'physicalDamageDealtToChampions': 6256,
#     'physicalDamageTaken': 4062,
#     'profileIcon': 1644,
#     'puuid': '0lTZ5Qb99lDz0jpKVO58pm1ML_3muXWlZRqvePY-PJwHfwif2ZtnssmlqZF9Ek2ssCRy3ogrXWK6CQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 19,
#     'spell2Casts': 38,
#     'spell3Casts': 4,
#     'spell4Casts': 2,
#     'summoner1Casts': 2,
#     'summoner1Id': 7,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'Rz59yDORZQbDXx0Mdx-9wnp1ScxDWI2YU7pfV85mytBqe6u9uDkloHG1DQ',
#     'summonerLevel': 85,
#     'summonerName': '음주운전피해자',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 20,
#     'timePlayed': 965,
#     'totalDamageDealt': 45929,
#     'totalDamageDealtToChampions': 6430,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 6960,
#     'totalHeal': 1076,
#     'totalHealsOnTeammates': 255,
#     'totalMinionsKilled': 120,
#     'totalTimeCCDealt': 355,
#     'totalTimeSpentDead': 48,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 180,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 12,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 2,
#     'wardsPlaced': 6,
#     'win': False},
#    {'assists': 3,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 3926,
#     'champLevel': 7,
#     'championId': 57,
#     'championName': 'Maokai',
#     'championTransform': 0,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 4767,
#     'deaths': 3,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'goldEarned': 3491,
#     'goldSpent': 2875,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3855,
#     'item1': 2055,
#     'item2': 2031,
#     'item3': 3009,
#     'item4': 3066,
#     'item5': 1029,
#     'item6': 3364,
#     'itemsPurchased': 13,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 427,
#     'magicDamageDealt': 5669,
#     'magicDamageDealtToChampions': 2657,
#     'magicDamageTaken': 2850,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 226, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 284, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 109, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 38, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8352, 'var1': 101, 'var2': 643, 'var3': 28}],
#        'style': 8300}]},
#     'physicalDamageDealt': 5499,
#     'physicalDamageDealtToChampions': 664,
#     'physicalDamageTaken': 5065,
#     'profileIcon': 3798,
#     'puuid': '3nn7InPfsJVU3_oP9FQb5eITYfwkV6kAzJezQsKDDSuUcz5hVnjW3WNkCXdgejVa4lQvWI0y--3UZQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 12,
#     'spell2Casts': 9,
#     'spell3Casts': 30,
#     'spell4Casts': 2,
#     'summoner1Casts': 3,
#     'summoner1Id': 14,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'tWdqIKXBLQ5FdS5OSLLrBjnZVOj14SM9QpszXSGgfVusdzg',
#     'summonerLevel': 528,
#     'summonerName': '수락고1',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 15,
#     'timePlayed': 965,
#     'totalDamageDealt': 17155,
#     'totalDamageDealtToChampions': 3667,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 8288,
#     'totalHeal': 2134,
#     'totalHealsOnTeammates': 157,
#     'totalMinionsKilled': 30,
#     'totalTimeCCDealt': 86,
#     'totalTimeSpentDead': 49,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 5986,
#     'trueDamageDealtToChampions': 346,
#     'trueDamageTaken': 372,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 2,
#     'unrealKills': 0,
#     'visionScore': 12,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 2,
#     'wardsPlaced': 5,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 126, 'pickTurn': 1},
#      {'championId': 107, 'pickTurn': 2},
#      {'championId': -1, 'pickTurn': 3},
#      {'championId': 412, 'pickTurn': 4},
#      {'championId': -1, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 15},
#      'dragon': {'first': False, 'kills': 1},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': True, 'kills': 2},
#      'tower': {'first': True, 'kills': 2}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 115, 'pickTurn': 6},
#      {'championId': 64, 'pickTurn': 7},
#      {'championId': 5, 'pickTurn': 8},
#      {'championId': 234, 'pickTurn': 9},
#      {'championId': 142, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 5},
#      'dragon': {'first': True, 'kills': 1},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 0}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}
